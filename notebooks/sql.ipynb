# %%
import pandas as pd
from datetime import datetime
import pandas as pd
import sqlalchemy as alch
from sqlalchemy import create_engine
from dotenv import load_dotenv
import os

# %%
load_dotenv()
# Out:
# True

# %%
password = os.getenv('password')

# %%
top20_csv = pd.read_csv('../data/my_top_20.csv')

# %%
top20_csv.rename(columns={'Unnamed: 0': 'names'}, inplace=True)

# %%
top20_csv
# Out:
#                      names  danceability  energy  key  loudness  mode  \
# 0              Si No Estás         0.537   0.421    5    -8.720     1
# 1                    QLONA         0.841   0.738    7    -7.455     0
# 2                   greedy         0.750   0.733    6    -3.180     0
# 3        Intro (Venezuela)         0.791   0.895    6    -4.801     0
# 4             Fire On Fire         0.584   0.408    1    -7.356     0
# 5        MI EX TENÍA RAZÓN         0.634   0.725    5    -4.945     0
# 6   Sin Tiempo Para Bailar         0.623   0.672    1    -6.353     0
# 7               Tamagotchi         0.870   0.664    1    -8.716     1
# 8                     LALA         0.708   0.737    1    -4.045     1
# 9             In The Stars         0.362   0.540   10    -6.031     1
# 10                 georgia         0.327   0.376    8   -10.540     1
# 11            Running Away         0.513   0.737    0    -5.023     0
# 12          Read your Mind         0.659   0.803    1    -5.043     1
# 13    Loving Means Leaving         0.489   0.405    8    -7.711     1
# 14               Peligrosa         0.816   0.721    8    -4.657     1
# 15                  Magnum         0.771   0.804    9    -4.175     1
# 16              Plan fatal         0.660   0.760    1    -2.871     1
# 17                   WANDA         0.724   0.631    4    -4.420     0
# 18                 Hey Mor         0.901   0.589    1    -6.713     0
# 19                AMARGURA         0.920   0.696    6    -3.356     0
#
#     speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0        0.0285       0.82700          0.000000    0.1380    0.524   98.224
# 1        0.3070       0.52000          0.000000    0.0892    0.484  169.918
# 2        0.0319       0.25600          0.000000    0.1140    0.844  111.018
# 3        0.0479       0.36200          0.000000    0.0916    0.617  106.535
# 4        0.0461       0.47600          0.000000    0.1800    0.333  115.129
# 5        0.0587       0.07760          0.000000    0.2110    0.795  159.845
# 6        0.0382       0.41500          0.000000    0.1570    0.213  125.178
# 7        0.0744       0.23300          0.000705    0.1410    0.840   98.013
# 8        0.0436       0.07390          0.001620    0.0955    0.607   91.986
# 9        0.0528       0.33800          0.000000    0.1390    0.300   78.007
# 10       0.0384       0.86100          0.000011    0.3450    0.285   80.114
# 11       0.0393       0.07920          0.000078    0.1080    0.115  138.032
# 12       0.0446       0.01020          0.000000    0.0746    0.620  120.080
# 13       0.0407       0.71000          0.000000    0.1040    0.462  108.095
# 14       0.0579       0.36100          0.000124    0.1240    0.542   95.029
# 15       0.1100       0.19400          0.000004    0.0781    0.625   93.824
# 16       0.0339       0.01070          0.000046    0.1580    0.824  127.492
# 17       0.0686       0.24900          0.000000    0.2130    0.957  176.076
# 18       0.2890       0.00302          0.000237    0.0992    0.399   98.002
# 19       0.0742       0.18300          0.000000    0.1490    0.545  106.966
#
#               type                      id  \
# 0   audio_features  2HafqoJbgXdtjwCOvNEF14
# 1   audio_features  5RqSsdzTNPX1uzkmlHCFvK
# 2   audio_features  3rUGC1vUpkDG9CZFHMur1t
# 3   audio_features  291cT7iO5eaC3dOHijXpNq
# 4   audio_features  7t3Xdbufg7q2onVsR8RBdY
# 5   audio_features  54zcJnb3tp9c5OVKREZ1Is
# 6   audio_features  0VqPLtmPr3UdQlQyCoGDgz
# 7   audio_features  5bfep56ypsHGIR4i5KPKJN
# 8   audio_features  7ABLbnD53cQK00mhcaOUVG
# 9   audio_features  1ei3hzQmrgealgRKFxIcWn
# 10  audio_features  0oWyUnmjpaFWzZNfnQmrGc
# 11  audio_features  1CNAp96nVFtzG0L48rDGnZ
# 12  audio_features  2Irr5XfPM6cyoKijHSCrqM
# 13  audio_features  2ySKEa16GDpwon90g1cILI
# 14  audio_features  3AsbVi6XAEGXoKOTfhzevi
# 15  audio_features  5fDMDKHhVCpUmAvTPJrYNh
# 16  audio_features  6yl12bWML644ZijpPjso5p
# 17  audio_features  0Iozrbed8spxoBnmtBMshO
# 18  audio_features  1zsPaEkglFvxjAhrM8yhpr
# 19  audio_features  505v13epFXodT9fVAJ6h8k
#
#                                      uri  \
# 0   spotify:track:2HafqoJbgXdtjwCOvNEF14
# 1   spotify:track:5RqSsdzTNPX1uzkmlHCFvK
# 2   spotify:track:3rUGC1vUpkDG9CZFHMur1t
# 3   spotify:track:291cT7iO5eaC3dOHijXpNq
# 4   spotify:track:7t3Xdbufg7q2onVsR8RBdY
# 5   spotify:track:54zcJnb3tp9c5OVKREZ1Is
# 6   spotify:track:0VqPLtmPr3UdQlQyCoGDgz
# 7   spotify:track:5bfep56ypsHGIR4i5KPKJN
# 8   spotify:track:7ABLbnD53cQK00mhcaOUVG
# 9   spotify:track:1ei3hzQmrgealgRKFxIcWn
# 10  spotify:track:0oWyUnmjpaFWzZNfnQmrGc
# 11  spotify:track:1CNAp96nVFtzG0L48rDGnZ
# 12  spotify:track:2Irr5XfPM6cyoKijHSCrqM
# 13  spotify:track:2ySKEa16GDpwon90g1cILI
# 14  spotify:track:3AsbVi6XAEGXoKOTfhzevi
# 15  spotify:track:5fDMDKHhVCpUmAvTPJrYNh
# 16  spotify:track:6yl12bWML644ZijpPjso5p
# 17  spotify:track:0Iozrbed8spxoBnmtBMshO
# 18  spotify:track:1zsPaEkglFvxjAhrM8yhpr
# 19  spotify:track:505v13epFXodT9fVAJ6h8k
#
#                                            track_href  \
# 0   https://api.spotify.com/v1/tracks/2HafqoJbgXdt...
# 1   https://api.spotify.com/v1/tracks/5RqSsdzTNPX1...
# 2   https://api.spotify.com/v1/tracks/3rUGC1vUpkDG...
# 3   https://api.spotify.com/v1/tracks/291cT7iO5eaC...
# 4   https://api.spotify.com/v1/tracks/7t3Xdbufg7q2...
# 5   https://api.spotify.com/v1/tracks/54zcJnb3tp9c...
# 6   https://api.spotify.com/v1/tracks/0VqPLtmPr3Ud...
# 7   https://api.spotify.com/v1/tracks/5bfep56ypsHG...
# 8   https://api.spotify.com/v1/tracks/7ABLbnD53cQK...
# 9   https://api.spotify.com/v1/tracks/1ei3hzQmrgea...
# 10  https://api.spotify.com/v1/tracks/0oWyUnmjpaFW...
# 11  https://api.spotify.com/v1/tracks/1CNAp96nVFtz...
# 12  https://api.spotify.com/v1/tracks/2Irr5XfPM6cy...
# 13  https://api.spotify.com/v1/tracks/2ySKEa16GDpw...
# 14  https://api.spotify.com/v1/tracks/3AsbVi6XAEGX...
# 15  https://api.spotify.com/v1/tracks/5fDMDKHhVCpU...
# 16  https://api.spotify.com/v1/tracks/6yl12bWML644...
# 17  https://api.spotify.com/v1/tracks/0Iozrbed8spx...
# 18  https://api.spotify.com/v1/tracks/1zsPaEkglFvx...
# 19  https://api.spotify.com/v1/tracks/505v13epFXod...
#
#                                          analysis_url  duration_ms  \
# 0   https://api.spotify.com/v1/audio-analysis/2Haf...       184061
# 1   https://api.spotify.com/v1/audio-analysis/5RqS...       172798
# 2   https://api.spotify.com/v1/audio-analysis/3rUG...       131872
# 3   https://api.spotify.com/v1/audio-analysis/291c...       126827
# 4   https://api.spotify.com/v1/audio-analysis/7t3X...       246735
# 5   https://api.spotify.com/v1/audio-analysis/54zc...       154375
# 6   https://api.spotify.com/v1/audio-analysis/0VqP...       205166
# 7   https://api.spotify.com/v1/audio-analysis/5bfe...       151000
# 8   https://api.spotify.com/v1/audio-analysis/7ABL...       197920
# 9   https://api.spotify.com/v1/audio-analysis/1ei3...       216410
# 10  https://api.spotify.com/v1/audio-analysis/0oWy...       210187
# 11  https://api.spotify.com/v1/audio-analysis/1CNA...       248232
# 12  https://api.spotify.com/v1/audio-analysis/2Irr...       207850
# 13  https://api.spotify.com/v1/audio-analysis/2ySK...       183828
# 14  https://api.spotify.com/v1/audio-analysis/3Asb...       165808
# 15  https://api.spotify.com/v1/audio-analysis/5fDM...       182467
# 16  https://api.spotify.com/v1/audio-analysis/6yl1...       221197
# 17  https://api.spotify.com/v1/audio-analysis/0Ioz...       160909
# 18  https://api.spotify.com/v1/audio-analysis/1zsP...       196600
# 19  https://api.spotify.com/v1/audio-analysis/505v...       170480
#
#     time_signature
# 0                4
# 1                4
# 2                1
# 3                3
# 4                4
# 5                4
# 6                4
# 7                4
# 8                4
# 9                3
# 10               4
# 11               4
# 12               4
# 13               3
# 14               4
# 15               4
# 16               4
# 17               4
# 18               4
# 19               4

# %%
password = os.getenv('password')
dbName = "spotify"
connectionData=f"mysql+pymysql://root:{password}@localhost/{dbName}"
engine = alch.create_engine(connectionData)

nombre_de_tabla = 'top_songs'
top20_csv.to_sql(nombre_de_tabla, con=engine, if_exists='replace', index=False)

engine.dispose()
