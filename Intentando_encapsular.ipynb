# %%
import pickle
import json
import pandas as pd
import numpy as np
import logging
from spotipy.exceptions import SpotifyException

#-----------------------------------------------#

import requests
import threading
import time
import os
from dotenv import load_dotenv

#-----------------------------------------------#

from spotipy.oauth2 import SpotifyOAuth
import spotipy
import spotipy.util as util

#-----------------------------------------------#

from sklearn.preprocessing import StandardScaler
from sklearn.metrics.pairwise import linear_kernel

# %%
load_dotenv()
# Out:
# True

# %%
'''Setting up a directory for caching Spotify data and initializig Spotify API credentials and user details using environment variables. 
It prepares for connecting to the Spotify API by defining the cache directory, client ID, client secret, redirect URI, and username.'''

CACHE_DIR = './spotify_data_cache'
cid = os.getenv('SPOTIPY_CLIENT_ID')
secret = os.getenv('SPOTIPY_CLIENT_SECRET')
redirect_uri = 'http://localhost:8080'
username = os.getenv('USERNAME')

# %% [markdown]
# def get_user_input():
#     client_id = input("Enter your Spotify Client ID: ")
#     client_secret = input("Enter your Spotify Client Secret: ")
#     username = input("Enter your Spotify Username: ")
#     return client_id, client_secret, username
#
# client_id, client_secret, username = get_user_input()

# %%
''' This code initializes Spotify API authorization with specific scopes for reading user's top tracks and modifying playlists'''

scope = 'user-top-read, playlist-modify-public, playlist-modify-private'
auth_manager = SpotifyOAuth(client_id=cid, client_secret=secret, redirect_uri=redirect_uri, scope=scope, username=username)
sp = spotipy.Spotify(auth_manager=auth_manager, requests_timeout=10)

# %%
import json
import os

def get_top_tracks(sp, user_id, time_range='short_term', limit=20, CACHE_DIR='./spotify_data_cache'):
    '''
    Retrieves a Spotify user's top tracks, using a cache file for efficient data access.
    Manages caching for different users separately.
    '''
    CACHE_FILE = 'all_top_tracks.json'
    cache_file_path = os.path.join(CACHE_DIR, CACHE_FILE)
    os.makedirs(CACHE_DIR, exist_ok=True)

    # Cargar la caché existente, si está disponible
    if os.path.exists(cache_file_path):
        with open(cache_file_path, 'r') as cache_file:
            all_top_tracks = json.load(cache_file)
    else:
        all_top_tracks = {}

    # Comprobar si los datos del usuario ya están en caché
    if user_id in all_top_tracks and time_range in all_top_tracks[user_id]:
        return all_top_tracks[user_id][time_range]

    # Obtener los top tracks y actualizar la caché
    top_tracks = sp.current_user_top_tracks(time_range=time_range, limit=limit)
    all_top_tracks.setdefault(user_id, {})[time_range] = top_tracks

    with open(cache_file_path, 'w') as cache_file:
        json.dump(all_top_tracks, cache_file)

    return top_tracks

top_tracks = get_top_tracks(sp, username)

# %%
for i, item in enumerate(top_tracks['items']):
    print(i+1, item['name'], '//', item['artists'][0]['name'])
# Out:
# 1 Si No Estás // iñigo quintero
# 2 QLONA // KAROL G
# 3 Fire On Fire // Sam Smith
# 4 MI EX TENÍA RAZÓN // KAROL G
# 5 Tamagotchi // GUNTTER
# 6 LALA // Myke Towers
# 7 Sin Tiempo Para Bailar // iñigo quintero
# 8 greedy // Tate McRae
# 9 Hey Mor // Ozuna
# 10 AMARGURA // KAROL G
# 11 In The Stars // Benson Boone
# 12 PERRO NEGRO // Bad Bunny
# 13 Según Quién // Maluma
# 14 WANDA // Quevedo
# 15 Columbia // Quevedo
# 16 Sobredosis // iñigo quintero
# 17 Déjala Que Vuelva (feat. Manuel Turizo) // Piso 21
# 18 BESO // ROSALÍA
# 19 QLONA // KAROL G
# 20 Hasta Que Dios Diga // Anuel AA

# %%
def create_tracks_dataframe(sp, top_tracks):
    '''
    This function processes a list of Spotify track data, extracting each track's ID, 
    name, and audio features, and then compiles this information into a Pandas DataFrame. 
    The DataFrame is indexed by track names for easy reference and analysis.
    '''

    tracks = top_tracks['items']
    track_ids = []  
    track_names = []
    features = []

    for track in tracks:
        track_id = track['id']
        track_name = track['name']
        audio_features = sp.audio_features(track_id)
        
        # Check if audio_features is not None
        if audio_features and len(audio_features) > 0:
            audio_features = audio_features[0]
        else:
            audio_features = None

        track_ids.append(track_id)
        track_names.append(track_name)
        features.append(audio_features)

    top_tracks_df = pd.DataFrame(features, index=track_names)
    
    return top_tracks_df, track_ids

# %%
'''Calling the previues function to create the new dataframe'''

top_tracks_df, track_ids = create_tracks_dataframe(sp, top_tracks)

# %%
def cleaning_df(track):
    
    '''The function cleaning_df takes a DataFrame track as input and returns a cleaned version, 
    top_tracks_clean, which contains only selected columns.'''
    
    top_tracks_clean = track[['id', 'danceability',	'energy',	'key',	'loudness',	'mode',	'speechiness',	'acousticness',	'instrumentalness',	'liveness',	'valence',	'tempo', 'duration_ms']]
    return top_tracks_clean

# %%
'''Calling the cleaning function to apply to the dataset'''

top_tracks_clean = cleaning_df(top_tracks_df)

# %%
def getting_id_artists(df):
    '''
    This function processes a DataFrame that contain Spotify track data, 
    and extracts the IDs of artists from its 'items' column. It prints the IDs and names 
    of the artists, and returns a list of these artist IDs.
    '''

    ids_artists = []
    print('|| Artists in my top 20: ||')
    print('===========================')

    for item in df['items']:
        artist_id = item['artists'][0]['id']
        artist_name = item['artists'][0]['name']
        print(f'{artist_id}: {artist_name}')
        ids_artists.append(artist_id)

    return ids_artists

# %%
ids_artists = getting_id_artists(top_tracks)
# Out:
# || Artists in my top 20: ||
# ===========================
# 0jbo7KFNMiIkfBR6ih0yhm: iñigo quintero
# 790FomKkXshlbRYZFtlgla: KAROL G
# 2wY79sveU1sp5g7SokKOiI: Sam Smith
# 790FomKkXshlbRYZFtlgla: KAROL G
# 3psizJPIbIEEctInvdWSZk: GUNTTER
# 7iK8PXO48WeuP03g8YR51W: Myke Towers
# 0jbo7KFNMiIkfBR6ih0yhm: iñigo quintero
# 45dkTj5sMRSjrmBSBeiHym: Tate McRae
# 1i8SpTcr7yvPOmcqrbnVXY: Ozuna
# 790FomKkXshlbRYZFtlgla: KAROL G
# 22wbnEMDvgVIAGdFeek6ET: Benson Boone
# 4q3ewBCX7sLwd24euuV69X: Bad Bunny
# 1r4hJ1h58CWwUQe3MxPuau: Maluma
# 52iwsT98xCoGgiGntTiR7K: Quevedo
# 52iwsT98xCoGgiGntTiR7K: Quevedo
# 0jbo7KFNMiIkfBR6ih0yhm: iñigo quintero
# 4bw2Am3p9ji3mYsXNXtQcd: Piso 21
# 7ltDVBr6mKbRvohxheJ9h1: ROSALÍA
# 790FomKkXshlbRYZFtlgla: KAROL G
# 2R21vXR83lH98kGeO99Y66: Anuel AA

# %%
""" This code converts the ids_artists list to a set to remove any repeated IDs and then back to a list, displaying the count of unique artists.
"""

ids_artists = list(set(ids_artists))
print(f'Number of artists (without repetitions): {len(ids_artists)}')
# Out:
# Number of artists (without repetitions): 14

# %%
def get_similar_artists(sp, ids_artists, CACHE_DIR, CACHE_FILE='all_similar_artists.pickle'):
    '''
    This function takes a Spotify client 'sp' and a list of artist IDs 'ids_artists', finds similar 
    artists for each artist in the list, and prints their IDs and names. It utilizes a single .pickle file 
    caching system to efficiently store and access this data for all artists. The function returns a list of the IDs 
    of these similar artists.
    '''

    print('Similar Artists:')
    print('=====================')

    cache_file = os.path.join(CACHE_DIR, CACHE_FILE)

    if os.path.exists(cache_file):
        with open(cache_file, 'rb') as file:
            all_similar_artists = pickle.load(file)
    else:
        all_similar_artists = {}

    ids_similar_artists = []

    for artist_id in ids_artists:
        if artist_id not in all_similar_artists:
            artists = sp.artist_related_artists(artist_id)['artists']
            all_similar_artists[artist_id] = artists
            with open(cache_file, 'wb') as file:
                pickle.dump(all_similar_artists, file)
        else:
            artists = all_similar_artists[artist_id]

        for item in artists:
            similar_artist_id = item['id']
            similar_artist_name = item['name']
            print(f'{similar_artist_id}: {similar_artist_name}')
            ids_similar_artists.append(similar_artist_id)
        
        time.sleep(1)
    return ids_similar_artists

# %%
ids_artists
# Out:
# ['7iK8PXO48WeuP03g8YR51W',
#  '3psizJPIbIEEctInvdWSZk',
#  '22wbnEMDvgVIAGdFeek6ET',
#  '1i8SpTcr7yvPOmcqrbnVXY',
#  '4q3ewBCX7sLwd24euuV69X',
#  '2R21vXR83lH98kGeO99Y66',
#  '790FomKkXshlbRYZFtlgla',
#  '0jbo7KFNMiIkfBR6ih0yhm',
#  '45dkTj5sMRSjrmBSBeiHym',
#  '7ltDVBr6mKbRvohxheJ9h1',
#  '4bw2Am3p9ji3mYsXNXtQcd',
#  '2wY79sveU1sp5g7SokKOiI',
#  '1r4hJ1h58CWwUQe3MxPuau',
#  '52iwsT98xCoGgiGntTiR7K']

# %%
'''Calling the get_similar_artists function to create a new list'''

ids_similar_artists = get_similar_artists(sp, ids_artists, CACHE_DIR)
# Out:
# Similar Artists:
# =====================
# 6nVcHLIgY5pE2YCl8ubca1: Jhayco
# 0Q8NcsJwoCbZOHHW63su5S: Mora
# 5XJDexmWFLWOkjOEjOVX3e: Eladio Carrion
# 77ziqFxp5gaInVrF2lj4ht: Sech
# 6w9ToX5slZ4uIdmD17hJ3c: Bryant Myers
# 52iwsT98xCoGgiGntTiR7K: Quevedo
# 0KPX4Ucy9dk82uj4GpKesn: Dalex
# 1mcTU81TzQhprhouKaTkpq: Rauw Alejandro
# 2cPqdH7XMvwaBJEVjheH8g: Jay Wheeler
# 2O8vbr4RYPpk6MRA4fio7u: Saiko
# 2LRoIwlKmHjgvigdNGBHNo: Feid
# 14zUHaJZo1mnYtn6IBRaRP: Justin Quiles
# 4SsVbpTthjScTS7U2hmr1X: Arcángel
# 47MpMsUfWtgyIIBEFOr4FE: Lunay
# 2DspEsT7UXGKd2VaaedgG4: Alex Rose
# 1TtXnWcUs0FCkaZDPGYHdf: Darell
# 1pf0MPKfKdvS8J779mS1Ay: Miky Woodz
# 3RtNN1VnooWEn3KQk03DUL: Noriel
# 0GM7qgcRCORpGnfcN2tCiB: Tainy
# 12vb80Km0Ew53ABfJOepVz: Ñengo Flow
# 06n23qw408xNUMGETWsmaL: HAMLIT SHORTY
# 3gvuPnQphwrMjq23LTUAFN: Sticks House
# 2LCB3Ikxw5T3vnigAVaMXy: Little Brian
# 3Wck1E7AcfrcW3beEPtPaU: Erreflexx
# 2C1Pj5TMq8QjqbwQ4tmDtO: Punto40
# 1PANUPmT5KUDGs3Xgkhw3T: Martinwhite
# 4kcrrhbTk7KqY1KKeonwKA: Smi-Lee
# 4tXFiCOQKSg5avRjHnYJAb: Profeta Yao Yao
# 7DXregrznS25AM30UY9sUU: King Savagge
# 5nhjhOrmCpnfUR6GHyU9ca: Noiss
# 5szJHKg5xeUlQ9pTqzdpic: Taiu
# 1NNRWkhwmcXRimFYSBpB1y: Yng Lvcas
# 4yjm4SvYqC5FFuLbB6TyHr: Bellakath
# 768O5GliF0bqscyghggrbE: Polimá Westcoast
# 0niAkxgT6y57bRbT0Ge94z: LiL CaKe
# 5DDpDYLDv4xasIBS6kp2wf: Loyaltty
# 41vcoPejPG3vv8emJ2R5Ox: Pablito Pesadilla
# 5RnwLXlnWPF57yzdmUnnvP: El Barto
# 5NenY2Jl9wwLRxf86go4Y8: Fran C
# 1GKIlPFdcewHtpDVCQ8zmJ: Brray
# 5TwUXL3I6RaLckHy8le2Hq: Thomas Day
# 5aHlyw2WWqZW0HLICBuv7U: Zach Hood
# 79AyR6ATpj2LTPxfb6FX50: Lauren Spencer Smith
# 7okSU80WTrn4LXlyXYbX3P: Clinton Kane
# 0znpFLuaey34oJTE1jHSnT: Alexander Stewart
# 6wlhqnATSJIc0NQ64VxOVJ: Matt Hansen
# 0sMAHzxguan2KpnKFZPW2d: Sadie Jean
# 0EiNdCUwM4B5GkTInLAyuj: Caleb Hearn
# 3IR6DvP0x2a6oUSist9UMu: elijah woods
# 2LkkwxA19J8C52wPQl5bG6: Jamie Miller
# 0fTSzq9jAh4c36UVb4V7CB: Alex Warren
# 3aHe9rMa5HFTjXHw8tEz0A: Jenna Raine
# 2S054G7qnCK45KY0XzpX30: Dylan Conrique
# 3QSQFmccmX81fWCUSPTS7y: Dean Lewis
# 2jHp7gQArCQrlMvdrIVFCg: Anson Seabra
# 0ekCwZGQUkAISV1h48jlHn: Rachel Grae
# 33NVpKoXjItPwUJTMZIOiY: David Kushner
# 45dkTj5sMRSjrmBSBeiHym: Tate McRae
# 3GxKJzJK4LpsYGXQrw77wz: Mimi Webb
# 5KsRA81UaMVKvLNiwDySfp: Jonah Kagen
# 329e4yvIujISKGKz1BZZbO: Farruko
# 1SupJlEpv7RS2tPNRaHViT: Nicky Jam
# 0eHQ9o50hj6ZDNBt6Ys1sD: Yandel
# 3E6xrwgnVfYCrCs0ePERDz: Wisin
# 1vyhD5VmyZ7KMfW5gqLgo5: J Balvin
# 77ziqFxp5gaInVrF2lj4ht: Sech
# 21451j1KhjAiaYKflxBjr1: Zion & Lennox
# 1GDbiv3spRmZ1XdM1jQbT7: NATTI NATASHA
# 0tmwSHipWxN12fsoLcFU3B: Manuel Turizo
# 4VMYDCV2IEDYJArk749S6m: Daddy Yankee
# 4SsVbpTthjScTS7U2hmr1X: Arcángel
# 2R21vXR83lH98kGeO99Y66: Anuel AA
# 1r4hJ1h58CWwUQe3MxPuau: Maluma
# 7iK8PXO48WeuP03g8YR51W: Myke Towers
# 47MpMsUfWtgyIIBEFOr4FE: Lunay
# 3EiLUeyEcA6fbRPSHkG5kb: De La Ghetto
# 3RtNN1VnooWEn3KQk03DUL: Noriel
# 4bw2Am3p9ji3mYsXNXtQcd: Piso 21
# 14zUHaJZo1mnYtn6IBRaRP: Justin Quiles
# 00me4Ke1LsvMxt5kydlMyU: Cosculluela
# 1mcTU81TzQhprhouKaTkpq: Rauw Alejandro
# 2R21vXR83lH98kGeO99Y66: Anuel AA
# 7iK8PXO48WeuP03g8YR51W: Myke Towers
# 2LRoIwlKmHjgvigdNGBHNo: Feid
# 6nVcHLIgY5pE2YCl8ubca1: Jhayco
# 1i8SpTcr7yvPOmcqrbnVXY: Ozuna
# 790FomKkXshlbRYZFtlgla: KAROL G
# 1vyhD5VmyZ7KMfW5gqLgo5: J Balvin
# 0Q8NcsJwoCbZOHHW63su5S: Mora
# 4SsVbpTthjScTS7U2hmr1X: Arcángel
# 5XJDexmWFLWOkjOEjOVX3e: Eladio Carrion
# 6w9ToX5slZ4uIdmD17hJ3c: Bryant Myers
# 3vQ0GE3mI0dAaxIMYe5g7z: Paulo Londra
# 77ziqFxp5gaInVrF2lj4ht: Sech
# 716NhGYqD1jl2wI1Qkgq36: Bizarrap
# 47MpMsUfWtgyIIBEFOr4FE: Lunay
# 4VMYDCV2IEDYJArk749S6m: Daddy Yankee
# 52iwsT98xCoGgiGntTiR7K: Quevedo
# 2IMZYfNi21MGqxopj9fWx8: Rels B
# 329e4yvIujISKGKz1BZZbO: Farruko
# 6w9ToX5slZ4uIdmD17hJ3c: Bryant Myers
# 7iK8PXO48WeuP03g8YR51W: Myke Towers
# 3RtNN1VnooWEn3KQk03DUL: Noriel
# 4SsVbpTthjScTS7U2hmr1X: Arcángel
# 12vb80Km0Ew53ABfJOepVz: Ñengo Flow
# 5XJDexmWFLWOkjOEjOVX3e: Eladio Carrion
# 6nVcHLIgY5pE2YCl8ubca1: Jhayco
# 5bWUlnPx9OYKsLiUJrhCA1: Jon Z
# 47MpMsUfWtgyIIBEFOr4FE: Lunay
# 1i8SpTcr7yvPOmcqrbnVXY: Ozuna
# 77ziqFxp5gaInVrF2lj4ht: Sech
# 00XhexlJEXQstHimpZN910: Brytiago
# 1pf0MPKfKdvS8J779mS1Ay: Miky Woodz
# 1mcTU81TzQhprhouKaTkpq: Rauw Alejandro
# 329e4yvIujISKGKz1BZZbO: Farruko
# 00me4Ke1LsvMxt5kydlMyU: Cosculluela
# 1TtXnWcUs0FCkaZDPGYHdf: Darell
# 1jSjfSgDjedJdi5MoyRu78: Lary Over
# 0Q8NcsJwoCbZOHHW63su5S: Mora
# 3EiLUeyEcA6fbRPSHkG5kb: De La Ghetto
# 1GDbiv3spRmZ1XdM1jQbT7: NATTI NATASHA
# 4obzFoKoKRHIphyHzJ35G3: Becky G
# 0tmwSHipWxN12fsoLcFU3B: Manuel Turizo
# 5dbaLmK5SHLLg8Z4CcTJpX: Greeicy
# 1mcTU81TzQhprhouKaTkpq: Rauw Alejandro
# 07YUOmWljBTXwIseAUd9TW: Sebastian Yatra
# 1i8SpTcr7yvPOmcqrbnVXY: Ozuna
# 28gNT5KBp7IjEOQoevXf9N: Camilo
# 1r4hJ1h58CWwUQe3MxPuau: Maluma
# 1vyhD5VmyZ7KMfW5gqLgo5: J Balvin
# 2LRoIwlKmHjgvigdNGBHNo: Feid
# 6w3SkAHYPsQ1bxV7VDlG5y: Cazzu
# 4VMYDCV2IEDYJArk749S6m: Daddy Yankee
# 2R21vXR83lH98kGeO99Y66: Anuel AA
# 77ziqFxp5gaInVrF2lj4ht: Sech
# 329e4yvIujISKGKz1BZZbO: Farruko
# 4bw2Am3p9ji3mYsXNXtQcd: Piso 21
# 5lwmRuXgjX8xIwlnauTZIP: Romeo Santos
# 1SupJlEpv7RS2tPNRaHViT: Nicky Jam
# 47MpMsUfWtgyIIBEFOr4FE: Lunay
# 29KrMIwUUqCvc66OHLcSMl: Inazio
# 1x8mAhfvCw7JXRX7Ild0lF: Hey Kid
# 5dviK29OUEuVZO9DyfSxPK: Pablo Assiego
# 5nyWlsjPKFjkzrn98UwzLS: Chema Quintero
# 1oF6Bxyk8UcW0DBH4jBGjk: Javi Chapela
# 1AsstJ8Cf7uQX92weRmZRz: mafalda cardenal
# 5N3YDBGT2gUzXgLDTwPRi5: Álvaro De Luna
# 6i0h6wBrfNkdf3eTUoelpP: Malmö 040
# 0CVOcYvRcSvOXyuR4YGKaC: Dani Fernández
# 7hF6UMdXdBUOtQbYJtxGtd: Guzmen
# 1yk1KXKWdvXVUC1TLAnO97: Besmaya
# 0oBiYchunKTMDesVICwrvL: Guitarricadelafuente
# 2fUMrRPj5xcEYXG5FoCTfw: Marina Reche
# 40Ippe6JeofRURQ4nbF8DT: Taburete
# 7Lemn0MD6Cb2QfmeZJ5BwS: Hakuna Group Music
# 6X8uzem5Dbl4l2so4CeexD: Nil Moliner
# 7eLcDZDYHXZCebtQmVFL25: Aitana
# 4XWTuDTFJpCJb34bUAB6ZD: Moni Motes
# 1RTZXV2Txeij9hW1C88mfs: Marlon
# 7D62OQfwvslnxJn9DkZm2F: Pole.
# 7pwufEBGfggjoI8twqlsmQ: Nessa Barrett
# 2kRfqPViCqYdSGhYSM9R0Q: Madison Beer
# 79AyR6ATpj2LTPxfb6FX50: Lauren Spencer Smith
# 5IH6FPUwQTxPSXurCrcIov: Alec Benjamin
# 74KM79TiuVKeVCqs8QtB0B: Sabrina Carpenter
# 1QRj3hoop9Mv5VvHQkwPEp: Olivia O'Brien
# 4tuJ0bMpJh08umKkEXKUI5: Gracie Abrams
# 4xnihxcoXWK3UqryOSnbw5: Sasha Alex Sloan
# 3GxKJzJK4LpsYGXQrw77wz: Mimi Webb
# 2W8yFh0Ga6Yf3jiayVxwkE: Dove Cameron
# 2WzaAvm2bBCf4pEhyuDgCY: Ruth B.
# 4VdV2qRAYBLINR6uU72V1J: Joshua Bassett
# 7Lk9V7E1u5gqSHmtcKlOqH: Sara Kays
# 2S054G7qnCK45KY0XzpX30: Dylan Conrique
# 0ZED1XzwlLHW4ZaG4lOT6m: Julia Michaels
# 3QSQFmccmX81fWCUSPTS7y: Dean Lewis
# 2yLzlEFtIS0Q9UkyBZdQA7: Jessie Murph
# 22wbnEMDvgVIAGdFeek6ET: Benson Boone
# 4Uc8Dsxct0oMqx0P6i60ea: Conan Gray
# 7okSU80WTrn4LXlyXYbX3P: Clinton Kane
# 3VHAySZQPlfGlNLslzXYpN: NATHY PELUSO
# 4F4pp8NUW08JuXwnoxglpN: Bad Gyal
# 3bvfu2KAve4lPHrhEFDZna: Lola Indigo
# 5TYxZTjIPqKM8K8NuP9woO: C. Tangana
# 7eLcDZDYHXZCebtQmVFL25: Aitana
# 4obzFoKoKRHIphyHzJ35G3: Becky G
# 7rOlQwf8OuFLFQp4aydjBt: Paloma Mami
# 6k8mwkKJKKjBILo7ypBspl: Ana Mena
# 1GDbiv3spRmZ1XdM1jQbT7: NATTI NATASHA
# 3Ces1OJeGOVGcUB0wPaPXJ: Mala Rodríguez
# 1mcTU81TzQhprhouKaTkpq: Rauw Alejandro
# 2p4aN0Uxkk3iT3HK0cJ2cJ: Tokischa
# 6i3DxIlAqnDkwELLw4aVrx: Lele Pons
# 790FomKkXshlbRYZFtlgla: KAROL G
# 52iwsT98xCoGgiGntTiR7K: Quevedo
# 7vXDAI8JwjW531ouMGbfcp: TINI
# 1vyhD5VmyZ7KMfW5gqLgo5: J Balvin
# 2UZIAOlrnyZmyzt1nuXr9y: Nicki Nicole
# 0tmwSHipWxN12fsoLcFU3B: Manuel Turizo
# 4SQdUpG4f7UbkJG3cJ2Iyj: Arca
# 2DP9xStkVVv753RBiEHXQB: Alkilados
# 5DUlefCLzVRzNWaNURTFpK: Cali Y El Dandee
# 1phfTBIocBW3UwqcYjaEN6: Mike Bahía
# 3ATyg4fGC9F8trfb0GRWmX: Joey Montana
# 5H1nN1SzW0qNeUEZvuXjAj: Danny Ocean
# 0tmwSHipWxN12fsoLcFU3B: Manuel Turizo
# 2ayNSoKPCRAfjp6hQ76hRu: Nacho
# 0eecdvMrqBftK0M1VKhaF4: CNCO
# 2wkoKEfS6dXwThbyTnZWFU: Mau y Ricky
# 5NS0854TqZQVoRmJKSWtFZ: Chino & Nacho
# 21451j1KhjAiaYKflxBjr1: Zion & Lennox
# 07YUOmWljBTXwIseAUd9TW: Sebastian Yatra
# 0vR2qb8m9WHeZ5ByCbimq2: Reik
# 5dbaLmK5SHLLg8Z4CcTJpX: Greeicy
# 2OnKRchqP7tT0FzTvWIFI7: Wolfine
# 3E6xrwgnVfYCrCs0ePERDz: Wisin
# 1GDbiv3spRmZ1XdM1jQbT7: NATTI NATASHA
# 7hIqJfRYGBWWT1Qxu6Cpd2: Andy Rivera
# 3PAwspMN27PDm81WwXDsMf: Reykon
# 1VrWc8r4AjrR8YfT0vlsc7: Chyno Miranda
# 6ydoSd3N2mwgwBHtF6K7eX: Calum Scott
# 4IWBUUAFIplrNtaOHcJPRM: James Arthur
# 6VuMaDnrHyPL1p4EHjYLi7: Charlie Puth
# 0X2BH1fck6amBIoJhDVmmJ: Ellie Goulding
# 4GNC7GD6oZMSxPGyXy4MNB: Lewis Capaldi
# 2gsggkzM5R49q6jpPvazou: Jessie J
# 5y2Xq6xcjJb2jVM54GHK3t: John Legend
# 5CCwRZC6euC8Odo6y9X8jr: Rita Ora
# 7n2wHs1TKAczGzO7Dd2rGr: Shawn Mendes
# 64M6ah0SkkRsnPGtGiRAbb: Bebe Rexha
# 4EzkuveR9pLvDVFNx6foYD: James Bay
# 31TPClRtHm23RisEBtV3X7: Justin Timberlake
# 2wUjUUtkb5lvLKcGKsKqsR: Alessia Cara
# 4Rxn7Im3LGfyRkY2FlHhWi: Nick Jonas
# 5WUlDfRSoLAfcVSX1WnrxN: Sia
# 5YGY8feqx7naU7z4HrwZM6: Miley Cyrus
# 5Pwc4xIPtQLFEnJriah9YJ: OneRepublic
# 6S2OmqARrzebs0tKUEyXyp: Demi Lovato
# 6LuN9FCkKOj5PcnpouEgny: Khalid
# 6JL8zeS1NmiOftqZTRgdTz: Meghan Trainor
# 1vyhD5VmyZ7KMfW5gqLgo5: J Balvin
# 1SupJlEpv7RS2tPNRaHViT: Nicky Jam
# 4bw2Am3p9ji3mYsXNXtQcd: Piso 21
# 329e4yvIujISKGKz1BZZbO: Farruko
# 3E6xrwgnVfYCrCs0ePERDz: Wisin
# 1GDbiv3spRmZ1XdM1jQbT7: NATTI NATASHA
# 0tmwSHipWxN12fsoLcFU3B: Manuel Turizo
# 0eHQ9o50hj6ZDNBt6Ys1sD: Yandel
# 07YUOmWljBTXwIseAUd9TW: Sebastian Yatra
# 1i8SpTcr7yvPOmcqrbnVXY: Ozuna
# 4VMYDCV2IEDYJArk749S6m: Daddy Yankee
# 28gNT5KBp7IjEOQoevXf9N: Camilo
# 21451j1KhjAiaYKflxBjr1: Zion & Lennox
# 0eecdvMrqBftK0M1VKhaF4: CNCO
# 1wZtkThiXbVNtj6hee6dz9: Wisin & Yandel
# 5DUlefCLzVRzNWaNURTFpK: Cali Y El Dandee
# 2ayNSoKPCRAfjp6hQ76hRu: Nacho
# 4obzFoKoKRHIphyHzJ35G3: Becky G
# 6XFITTl7cFTdopDY3lUdlY: J Alvarez
# 77ziqFxp5gaInVrF2lj4ht: Sech
# 2O8vbr4RYPpk6MRA4fio7u: Saiko
# 0Q8NcsJwoCbZOHHW63su5S: Mora
# 2LRoIwlKmHjgvigdNGBHNo: Feid
# 7iK8PXO48WeuP03g8YR51W: Myke Towers
# 6nVcHLIgY5pE2YCl8ubca1: Jhayco
# 5XJDexmWFLWOkjOEjOVX3e: Eladio Carrion
# 1bAftSH8umNcGZ0uyV7LMg: Duki
# 716NhGYqD1jl2wI1Qkgq36: Bizarrap
# 5Y3MV9DZ0d87NnVm56qSY1: Tiago PZK
# 2CCgb0KApjfQDuTppovpf8: Rvfv
# 3lY9Fxceu60W1rbon7PkuF: Omar Montes
# 19HM5j0ULGSmEoRcrSe5x3: Milo j
# 0AqlFI0tz2DsEoJlKSIiT9: Emilia
# 3qsKSpcV3ncke3hw52JSMB: Young Miko
# 0FwnPHExlRRxEZPLAi5tmG: JC Reyes
# 0GM7qgcRCORpGnfcN2tCiB: Tainy
# 1mcTU81TzQhprhouKaTkpq: Rauw Alejandro
# 0dUyjgCyjfj5eMx6bX2TWf: FMK
# 2UZIAOlrnyZmyzt1nuXr9y: Nicki Nicole
# 1DxLCyH42yaHKGK3cl5bvG: Maria Becerra

# %%
ids_artists.extend(ids_similar_artists)

# %%
ids_artists = list(set(ids_artists))
print(f'Number of artists (without repetitions): {len(ids_artists)}')
# Out:
# Number of artists (without repetitions): 187

# %%
def get_new_releases(sp, limit=20):
    '''
    This function uses a Spotify client 'sp' to fetch new releases. It uses a .pickle file in the 
    'spotify_data_cache' directory as a cache to store and efficiently access the data. 
    It returns the album data with a default limit that can be adjusted.
    '''

    cache_file = os.path.join(CACHE_DIR, 'new_releases_cache.pickle')

    if os.path.exists(cache_file):
        try:
            with open(cache_file, 'rb') as file:
                new_releases = pickle.load(file)
            return new_releases
        except Exception as e:
            print(f"Error reading from the cache: {e}")

    try:
        new_releases = sp.new_releases(limit=limit)['albums']
        with open(cache_file, 'wb') as file:
            pickle.dump(new_releases, file)
        return new_releases
    except Exception as e:
        print(f"Error fetching new releases: {e}")
        return None

new_releases_data = get_new_releases(sp)

# %%
def getting_id_artists(df):

    print('')
    print('Artists with new releases')
    print('=====================')
    for item in df['items']:
        artist_id = item['artists'][0]['id']
        artist_name = item['artists'][0]['name']
        album_name = item['name']  
        release_date = item['release_date']
        print(f'{artist_id}: {artist_name} - // {album_name}, {release_date}')
        ids_artists.append(artist_id)
    return ids_artists

# %%
ids_artists = getting_id_artists(new_releases_data)
# Out:
# Artists with new releases
# =====================
# 1Mw40k757jZuiL0NIJpdO5: GULEED - // Cuando Menos Lo Espera, 2023-07-07
# 6k8mwkKJKKjBILo7ypBspl: Ana Mena - // bellodrama, 2023-03-24
# 7iK8PXO48WeuP03g8YR51W: Myke Towers - // LA VIDA ES UNA, 2023-03-23
# 5XJDexmWFLWOkjOEjOVX3e: Eladio Carrion - // 3MEN2 KBRN, 2023-03-17
# 790FomKkXshlbRYZFtlgla: KAROL G - // MAÑANA SERÁ BONITO, 2023-02-24
# 2auC28zjQyVTsiZKNgPRGs: RM - // Indigo, 2022-12-02
# 6KImCVD70vtIoJWnq6nGn3: Harry Styles - // Harry's House, 2022-05-20
# 4q3ewBCX7sLwd24euuV69X: Bad Bunny - // Un Verano Sin Ti, 2022-05-06
# 2R21vXR83lH98kGeO99Y66: Anuel AA - // Las Leyendas Nunca Mueren, 2021-11-26
# 4dpARuHxo51G3z768sgnrY: Adele - // 30, 2021-11-19
# 6eUKZXaKkcviH0Ku9w2n3V: Ed Sheeran - // =, 2021-10-29
# 4gzpq5DPGxSnKTe4SA8HAU: Coldplay - // Music Of The Spheres, 2021-10-15
# 53KwLdlmrlCelAZMaLVZqU: James Blake - // Friends That Break Your Heart, 2021-10-08
# 4MzJMcHQBl9SIYSjwWn8QW: Spiritbox - // Eternal Blue, 2021-09-17
# 1vyhD5VmyZ7KMfW5gqLgo5: J Balvin - // JOSE, 2021-09-10
# 5K4W6rqBFWDnAN6FQUkS6x: Kanye West - // Donda, 2021-08-29
# 3TVXtAsR1Inumwj472S9r4: Drake - // Certified Lover Boy, 2021-09-03
# 6nVcHLIgY5pE2YCl8ubca1: Jhayco - // Timelezz, 2021-09-03
# 6Xgp2XMz1fhVYe7i6yNAax: Trippie Redd - // Trip At Knight, 2021-08-20
# 163tK9Wjr9P9DmM0AVK7lm: Lorde - // Solar Power, 2021-08-20

# %%
ids_artists = list(set(ids_artists))
print(f'Number of artists (without repetitions): {len(ids_artists)}')
# Out:
# Number of artists (without repetitions): 199

# %%
def get_album_ids(sp, ids_artists, CACHE_DIR='./spotify_data_cache', CACHE_FILE='artist_albums_cache.pickle'):
    '''
    Retrieves album IDs for each artist in 'ids_artists' using Spotify client 'sp'.
    Utilizes caching and a 3-second delay to avoid rate limiting.
    Returns a list of album IDs.
    '''

    os.makedirs(CACHE_DIR, exist_ok=True)
    cache_file_path = os.path.join(CACHE_DIR, CACHE_FILE)

    # Load cache if exists
    if os.path.exists(cache_file_path):
        with open(cache_file_path, 'rb') as file:
            cached_data = pickle.load(file)
    else:
        cached_data = {}

    id_albums = []
    nartists = len(ids_artists)

    for i, id_artist in enumerate(ids_artists):
        print(f'Processing artist {i+1} of {nartists}...')

        if id_artist in cached_data:
            id_albums.extend(cached_data[id_artist])
        else:
            try:
                albums = sp.artist_albums(id_artist, limit=1)  # to avoid having a huge list
                album_ids = [album['id'] for album in albums['items']]
                id_albums.extend(album_ids)
                cached_data[id_artist] = album_ids

                time.sleep(1)  # Adds 3-seconds delay

                # Save updated cache when new data is retrieved
                with open(cache_file_path, 'wb') as file:
                    pickle.dump(cached_data, file)

            except requests.exceptions.HTTPError as e:
                if e.response.status_code == 429:
                    retry_after = int(e.response.headers.get('Retry-After', 3))
                    print(f"Rate limit exceeded, waiting for {retry_after} seconds.")
                    time.sleep(retry_after)
                    continue
                else:
                    print(f"Error processing artist {id_artist}: {e}")

    print('Done!')
    return id_albums

# %%
id_albums = get_album_ids(sp, ids_artists)
# Out:
# Processing artist 1 of 199...
# Processing artist 2 of 199...
# Processing artist 3 of 199...
# Processing artist 4 of 199...
# Processing artist 5 of 199...
# Processing artist 6 of 199...
# Processing artist 7 of 199...
# Processing artist 8 of 199...
# Processing artist 9 of 199...
# Processing artist 10 of 199...
# Processing artist 11 of 199...
# Processing artist 12 of 199...
# Processing artist 13 of 199...
# Processing artist 14 of 199...
# Processing artist 15 of 199...
# Processing artist 16 of 199...
# Processing artist 17 of 199...
# Processing artist 18 of 199...
# Processing artist 19 of 199...
# Processing artist 20 of 199...
# Processing artist 21 of 199...
# Processing artist 22 of 199...
# Processing artist 23 of 199...
# Processing artist 24 of 199...
# Processing artist 25 of 199...
# Processing artist 26 of 199...
# Processing artist 27 of 199...
# Processing artist 28 of 199...
# Processing artist 29 of 199...
# Processing artist 30 of 199...
# Processing artist 31 of 199...
# Processing artist 32 of 199...
# Processing artist 33 of 199...
# Processing artist 34 of 199...
# Processing artist 35 of 199...
# Processing artist 36 of 199...
# Processing artist 37 of 199...
# Processing artist 38 of 199...
# Processing artist 39 of 199...
# Processing artist 40 of 199...
# Processing artist 41 of 199...
# Processing artist 42 of 199...
# Processing artist 43 of 199...
# Processing artist 44 of 199...
# Processing artist 45 of 199...
# Processing artist 46 of 199...
# Processing artist 47 of 199...
# Processing artist 48 of 199...
# Processing artist 49 of 199...
# Processing artist 50 of 199...
# Processing artist 51 of 199...
# Processing artist 52 of 199...
# Processing artist 53 of 199...
# Processing artist 54 of 199...
# Processing artist 55 of 199...
# Processing artist 56 of 199...
# Processing artist 57 of 199...
# Processing artist 58 of 199...
# Processing artist 59 of 199...
# Processing artist 60 of 199...
# Processing artist 61 of 199...
# Processing artist 62 of 199...
# Processing artist 63 of 199...
# Processing artist 64 of 199...
# Processing artist 65 of 199...
# Processing artist 66 of 199...
# Processing artist 67 of 199...
# Processing artist 68 of 199...
# Processing artist 69 of 199...
# Processing artist 70 of 199...
# Processing artist 71 of 199...
# Processing artist 72 of 199...
# Processing artist 73 of 199...
# Processing artist 74 of 199...
# Processing artist 75 of 199...
# Processing artist 76 of 199...
# Processing artist 77 of 199...
# Processing artist 78 of 199...
# Processing artist 79 of 199...
# Processing artist 80 of 199...
# Processing artist 81 of 199...
# Processing artist 82 of 199...
# Processing artist 83 of 199...
# Processing artist 84 of 199...
# Processing artist 85 of 199...
# Processing artist 86 of 199...
# Processing artist 87 of 199...
# Processing artist 88 of 199...
# Processing artist 89 of 199...
# Processing artist 90 of 199...
# Processing artist 91 of 199...
# Processing artist 92 of 199...
# Processing artist 93 of 199...
# Processing artist 94 of 199...
# Processing artist 95 of 199...
# Processing artist 96 of 199...
# Processing artist 97 of 199...
# Processing artist 98 of 199...
# Processing artist 99 of 199...
# Processing artist 100 of 199...
# Processing artist 101 of 199...
# Processing artist 102 of 199...
# Processing artist 103 of 199...
# Processing artist 104 of 199...
# Processing artist 105 of 199...
# Processing artist 106 of 199...
# Processing artist 107 of 199...
# Processing artist 108 of 199...
# Processing artist 109 of 199...
# Processing artist 110 of 199...
# Processing artist 111 of 199...
# Processing artist 112 of 199...
# Processing artist 113 of 199...
# Processing artist 114 of 199...
# Processing artist 115 of 199...
# Processing artist 116 of 199...
# Processing artist 117 of 199...
# Processing artist 118 of 199...
# Processing artist 119 of 199...
# Processing artist 120 of 199...
# Processing artist 121 of 199...
# Processing artist 122 of 199...
# Processing artist 123 of 199...
# Processing artist 124 of 199...
# Processing artist 125 of 199...
# Processing artist 126 of 199...
# Processing artist 127 of 199...
# Processing artist 128 of 199...
# Processing artist 129 of 199...
# Processing artist 130 of 199...
# Processing artist 131 of 199...
# Processing artist 132 of 199...
# Processing artist 133 of 199...
# Processing artist 134 of 199...
# Processing artist 135 of 199...
# Processing artist 136 of 199...
# Processing artist 137 of 199...
# Processing artist 138 of 199...
# Processing artist 139 of 199...
# Processing artist 140 of 199...
# Processing artist 141 of 199...
# Processing artist 142 of 199...
# Processing artist 143 of 199...
# Processing artist 144 of 199...
# Processing artist 145 of 199...
# Processing artist 146 of 199...
# Processing artist 147 of 199...
# Processing artist 148 of 199...
# Processing artist 149 of 199...
# Processing artist 150 of 199...
# Processing artist 151 of 199...
# Processing artist 152 of 199...
# Processing artist 153 of 199...
# Processing artist 154 of 199...
# Processing artist 155 of 199...
# Processing artist 156 of 199...
# Processing artist 157 of 199...
# Processing artist 158 of 199...
# Processing artist 159 of 199...
# Processing artist 160 of 199...
# Processing artist 161 of 199...
# Processing artist 162 of 199...
# Processing artist 163 of 199...
# Processing artist 164 of 199...
# Processing artist 165 of 199...
# Processing artist 166 of 199...
# Processing artist 167 of 199...
# Processing artist 168 of 199...
# Processing artist 169 of 199...
# Processing artist 170 of 199...
# Processing artist 171 of 199...
# Processing artist 172 of 199...
# Processing artist 173 of 199...
# Processing artist 174 of 199...
# Processing artist 175 of 199...
# Processing artist 176 of 199...
# Processing artist 177 of 199...
# Processing artist 178 of 199...
# Processing artist 179 of 199...
# Processing artist 180 of 199...
# Processing artist 181 of 199...
# Processing artist 182 of 199...
# Processing artist 183 of 199...
# Processing artist 184 of 199...
# Processing artist 185 of 199...
# Processing artist 186 of 199...
# Processing artist 187 of 199...
# Processing artist 188 of 199...
# Processing artist 189 of 199...
# Processing artist 190 of 199...
# Processing artist 191 of 199...
# Processing artist 192 of 199...
# Processing artist 193 of 199...
# Processing artist 194 of 199...
# Processing artist 195 of 199...
# Processing artist 196 of 199...
# Processing artist 197 of 199...
# Processing artist 198 of 199...
# Processing artist 199 of 199...
# Done!

# %%
def get_track_ids(sp, id_albums, CACHE_DIR='./spotify_data_cache', CACHE_FILE='album_tracks_cache.pickle'):
    '''
    Retrieves track IDs for each album in 'id_albums' using Spotify client 'sp'.
    Utilizes a pickle file for caching. Adds new songs to cache without overwriting existing data.
    '''

    os.makedirs(CACHE_DIR, exist_ok=True)
    cache_file_path = os.path.join(CACHE_DIR, CACHE_FILE)
    cache_updated = False

    # Load cache if available
    if os.path.exists(cache_file_path):
        with open(cache_file_path, 'rb') as file:
            cached_data = pickle.load(file)
    else:
        cached_data = {}

    id_tracks = []
    for i, id_album in enumerate(id_albums):
        print(f'Processing album {i+1} of {len(id_albums)}...')
        cached_album_tracks = cached_data.get(id_album, [])

        try:
            album_tracks = sp.album_tracks(id_album, limit=3)['items']
            new_track_ids = [track['id'] for track in album_tracks if track['id'] not in cached_album_tracks]

            if new_track_ids:
                cached_data[id_album] = cached_album_tracks + new_track_ids
                cache_updated = True

            id_tracks.extend(cached_album_tracks + new_track_ids)
            time.sleep(1)  # Adding delay

        except requests.exceptions.HTTPError as e:
            handle_http_error(e)

    # Save updated cache
    if cache_updated:
        with open(cache_file_path, 'wb') as file:
            pickle.dump(cached_data, file)

    print(f'Done! Total number of pre-candidate tracks: {len(id_tracks)}')
    return id_tracks

def handle_http_error(e):
    if e.response.status_code == 429:
        retry_after = int(e.response.headers.get('Retry-After', 2))
        print(f"Rate limit exceeded, waiting for {retry_after} seconds.")
        time.sleep(retry_after)
    else:
        print(f"HTTP Error: {e}")

# %%
id_tracks = get_track_ids(sp, id_albums)
# Out:
# Processing album 1 of 398...
# Processing album 2 of 398...
# Processing album 3 of 398...
# Processing album 4 of 398...
# Processing album 5 of 398...
# Processing album 6 of 398...
# Processing album 7 of 398...
# Processing album 8 of 398...
# Processing album 9 of 398...
# Processing album 10 of 398...
# Processing album 11 of 398...
# Processing album 12 of 398...
# Processing album 13 of 398...
# Processing album 14 of 398...
# Processing album 15 of 398...
# Processing album 16 of 398...
# Processing album 17 of 398...
# Processing album 18 of 398...
# Processing album 19 of 398...
# Processing album 20 of 398...
# Processing album 21 of 398...
# Processing album 22 of 398...
# Processing album 23 of 398...
# Processing album 24 of 398...
# Processing album 25 of 398...
# Processing album 26 of 398...
# Processing album 27 of 398...
# Processing album 28 of 398...
# Processing album 29 of 398...
# Processing album 30 of 398...
# Processing album 31 of 398...
# Processing album 32 of 398...
# Processing album 33 of 398...
# Processing album 34 of 398...
# Processing album 35 of 398...
# Processing album 36 of 398...
# Processing album 37 of 398...
# Processing album 38 of 398...
# Processing album 39 of 398...
# Processing album 40 of 398...
# Processing album 41 of 398...
# Processing album 42 of 398...
# Processing album 43 of 398...
# Processing album 44 of 398...
# Processing album 45 of 398...
# Processing album 46 of 398...
# Processing album 47 of 398...
# Processing album 48 of 398...
# Processing album 49 of 398...
# Processing album 50 of 398...
# Processing album 51 of 398...
# Processing album 52 of 398...
# Processing album 53 of 398...
# Processing album 54 of 398...
# Processing album 55 of 398...
# Processing album 56 of 398...
# Processing album 57 of 398...
# Processing album 58 of 398...
# Processing album 59 of 398...
# Processing album 60 of 398...
# Processing album 61 of 398...
# Processing album 62 of 398...
# Processing album 63 of 398...
# Processing album 64 of 398...
# Processing album 65 of 398...
# Processing album 66 of 398...
# Processing album 67 of 398...
# Processing album 68 of 398...
# Processing album 69 of 398...
# Processing album 70 of 398...
# Processing album 71 of 398...
# Processing album 72 of 398...
# Processing album 73 of 398...
# Processing album 74 of 398...
# Processing album 75 of 398...
# Processing album 76 of 398...
# Processing album 77 of 398...
# Processing album 78 of 398...
# Processing album 79 of 398...
# Processing album 80 of 398...
# Processing album 81 of 398...
# Processing album 82 of 398...
# Processing album 83 of 398...
# Processing album 84 of 398...
# Processing album 85 of 398...
# Processing album 86 of 398...
# Processing album 87 of 398...
# Processing album 88 of 398...
# Processing album 89 of 398...
# Processing album 90 of 398...
# Processing album 91 of 398...
# Processing album 92 of 398...
# Processing album 93 of 398...
# Processing album 94 of 398...
# Processing album 95 of 398...
# Processing album 96 of 398...
# Processing album 97 of 398...
# Processing album 98 of 398...
# Processing album 99 of 398...
# Processing album 100 of 398...
# Processing album 101 of 398...
# Processing album 102 of 398...
# Processing album 103 of 398...
# Processing album 104 of 398...
# Processing album 105 of 398...
# Processing album 106 of 398...
# Processing album 107 of 398...
# Processing album 108 of 398...
# Processing album 109 of 398...
# Processing album 110 of 398...
# Processing album 111 of 398...
# Processing album 112 of 398...
# Processing album 113 of 398...
# Processing album 114 of 398...
# Processing album 115 of 398...
# Processing album 116 of 398...
# Processing album 117 of 398...
# Processing album 118 of 398...
# Processing album 119 of 398...
# Processing album 120 of 398...
# Processing album 121 of 398...
# Processing album 122 of 398...
# Processing album 123 of 398...
# Processing album 124 of 398...
# Processing album 125 of 398...
# Processing album 126 of 398...
# Processing album 127 of 398...
# Processing album 128 of 398...
# Processing album 129 of 398...
# Processing album 130 of 398...
# Processing album 131 of 398...
# Processing album 132 of 398...
# Processing album 133 of 398...
# Processing album 134 of 398...
# Processing album 135 of 398...
# Processing album 136 of 398...
# Processing album 137 of 398...
# Processing album 138 of 398...
# Processing album 139 of 398...
# Processing album 140 of 398...
# Processing album 141 of 398...
# Processing album 142 of 398...
# Processing album 143 of 398...
# Processing album 144 of 398...
# Processing album 145 of 398...
# Processing album 146 of 398...
# Processing album 147 of 398...
# Processing album 148 of 398...
# Processing album 149 of 398...
# Processing album 150 of 398...
# Processing album 151 of 398...
# Processing album 152 of 398...
# Processing album 153 of 398...
# Processing album 154 of 398...
# Processing album 155 of 398...
# Processing album 156 of 398...
# Processing album 157 of 398...
# Processing album 158 of 398...
# Processing album 159 of 398...
# Processing album 160 of 398...
# Processing album 161 of 398...
# Processing album 162 of 398...
# Processing album 163 of 398...
# Processing album 164 of 398...
# Processing album 165 of 398...
# Processing album 166 of 398...
# Processing album 167 of 398...
# Processing album 168 of 398...
# Processing album 169 of 398...
# Processing album 170 of 398...
# Processing album 171 of 398...
# Processing album 172 of 398...
# Processing album 173 of 398...
# Processing album 174 of 398...
# Processing album 175 of 398...
# Processing album 176 of 398...
# Processing album 177 of 398...
# Processing album 178 of 398...
# Processing album 179 of 398...
# Processing album 180 of 398...
# Processing album 181 of 398...
# Processing album 182 of 398...
# Processing album 183 of 398...
# Processing album 184 of 398...
# Processing album 185 of 398...
# Processing album 186 of 398...
# Processing album 187 of 398...
# Processing album 188 of 398...
# Processing album 189 of 398...
# Processing album 190 of 398...
# Processing album 191 of 398...
# Processing album 192 of 398...
# Processing album 193 of 398...
# Processing album 194 of 398...
# Processing album 195 of 398...
# Processing album 196 of 398...
# Processing album 197 of 398...
# Processing album 198 of 398...
# Processing album 199 of 398...
# Processing album 200 of 398...
# Processing album 201 of 398...
# Processing album 202 of 398...
# Processing album 203 of 398...
# Processing album 204 of 398...
# Processing album 205 of 398...
# Processing album 206 of 398...
# Processing album 207 of 398...
# Processing album 208 of 398...
# Processing album 209 of 398...
# Processing album 210 of 398...
# Processing album 211 of 398...
# Processing album 212 of 398...
# Processing album 213 of 398...
# Processing album 214 of 398...
# Processing album 215 of 398...
# Processing album 216 of 398...
# Processing album 217 of 398...
# Processing album 218 of 398...
# Processing album 219 of 398...
# Processing album 220 of 398...
# Processing album 221 of 398...
# Processing album 222 of 398...
# Processing album 223 of 398...
# Processing album 224 of 398...
# Processing album 225 of 398...
# Processing album 226 of 398...
# Processing album 227 of 398...
# Processing album 228 of 398...
# Processing album 229 of 398...
# Processing album 230 of 398...
# Processing album 231 of 398...
# Processing album 232 of 398...
# Processing album 233 of 398...
# Processing album 234 of 398...
# Processing album 235 of 398...
# Processing album 236 of 398...
# Processing album 237 of 398...
# Processing album 238 of 398...
# Processing album 239 of 398...
# Processing album 240 of 398...
# Processing album 241 of 398...
# Processing album 242 of 398...
# Processing album 243 of 398...
# Processing album 244 of 398...
# Processing album 245 of 398...
# Processing album 246 of 398...
# Processing album 247 of 398...
# Processing album 248 of 398...
# Processing album 249 of 398...
# Processing album 250 of 398...
# Processing album 251 of 398...
# Processing album 252 of 398...
# Processing album 253 of 398...
# Processing album 254 of 398...
# Processing album 255 of 398...
# Processing album 256 of 398...
# Processing album 257 of 398...
# Processing album 258 of 398...
# Processing album 259 of 398...
# Processing album 260 of 398...
# Processing album 261 of 398...
# Processing album 262 of 398...
# Processing album 263 of 398...
# Processing album 264 of 398...
# Processing album 265 of 398...
# Processing album 266 of 398...
# Processing album 267 of 398...
# Processing album 268 of 398...
# Processing album 269 of 398...
# Processing album 270 of 398...
# Processing album 271 of 398...
# Processing album 272 of 398...
# Processing album 273 of 398...
# Processing album 274 of 398...
# Processing album 275 of 398...
# Processing album 276 of 398...
# Processing album 277 of 398...
# Processing album 278 of 398...
# Processing album 279 of 398...
# Processing album 280 of 398...
# Processing album 281 of 398...
# Processing album 282 of 398...
# Processing album 283 of 398...
# Processing album 284 of 398...
# Processing album 285 of 398...
# Processing album 286 of 398...
# Processing album 287 of 398...
# Processing album 288 of 398...
# Processing album 289 of 398...
# Processing album 290 of 398...
# Processing album 291 of 398...
# Processing album 292 of 398...
# Processing album 293 of 398...
# Processing album 294 of 398...
# Processing album 295 of 398...
# Processing album 296 of 398...
# Processing album 297 of 398...
# Processing album 298 of 398...
# Processing album 299 of 398...
# Processing album 300 of 398...
# Processing album 301 of 398...
# Processing album 302 of 398...
# Processing album 303 of 398...
# Processing album 304 of 398...
# Processing album 305 of 398...
# Processing album 306 of 398...
# Processing album 307 of 398...
# Processing album 308 of 398...
# Processing album 309 of 398...
# Processing album 310 of 398...
# Processing album 311 of 398...
# Processing album 312 of 398...
# Processing album 313 of 398...
# Processing album 314 of 398...
# Processing album 315 of 398...
# Processing album 316 of 398...
# Processing album 317 of 398...
# Processing album 318 of 398...
# Processing album 319 of 398...
# Processing album 320 of 398...
# Processing album 321 of 398...
# Processing album 322 of 398...
# Processing album 323 of 398...
# Processing album 324 of 398...
# Processing album 325 of 398...
# Processing album 326 of 398...
# Processing album 327 of 398...
# Processing album 328 of 398...
# Processing album 329 of 398...
# Processing album 330 of 398...
# Processing album 331 of 398...
# Processing album 332 of 398...
# Processing album 333 of 398...
# Processing album 334 of 398...
# Processing album 335 of 398...
# Processing album 336 of 398...
# Processing album 337 of 398...
# Processing album 338 of 398...
# Processing album 339 of 398...
# Processing album 340 of 398...
# Processing album 341 of 398...
# Processing album 342 of 398...
# Processing album 343 of 398...
# Processing album 344 of 398...
# Processing album 345 of 398...
# Processing album 346 of 398...
# Processing album 347 of 398...
# Processing album 348 of 398...
# Processing album 349 of 398...
# Processing album 350 of 398...
# Processing album 351 of 398...
# Processing album 352 of 398...
# Processing album 353 of 398...
# Processing album 354 of 398...
# Processing album 355 of 398...
# Processing album 356 of 398...
# Processing album 357 of 398...
# Processing album 358 of 398...
# Processing album 359 of 398...
# Processing album 360 of 398...
# Processing album 361 of 398...
# Processing album 362 of 398...
# Processing album 363 of 398...
# Processing album 364 of 398...
# Processing album 365 of 398...
# Processing album 366 of 398...
# Processing album 367 of 398...
# Processing album 368 of 398...
# Processing album 369 of 398...
# Processing album 370 of 398...
# Processing album 371 of 398...
# Processing album 372 of 398...
# Processing album 373 of 398...
# Processing album 374 of 398...
# Processing album 375 of 398...
# Processing album 376 of 398...
# Processing album 377 of 398...
# Processing album 378 of 398...
# Processing album 379 of 398...
# Processing album 380 of 398...
# Processing album 381 of 398...
# Processing album 382 of 398...
# Processing album 383 of 398...
# Processing album 384 of 398...
# Processing album 385 of 398...
# Processing album 386 of 398...
# Processing album 387 of 398...
# Processing album 388 of 398...
# Processing album 389 of 398...
# Processing album 390 of 398...
# Processing album 391 of 398...
# Processing album 392 of 398...
# Processing album 393 of 398...
# Processing album 394 of 398...
# Processing album 395 of 398...
# Processing album 396 of 398...
# Processing album 397 of 398...
# Processing album 398 of 398...
# Done! Total number of pre-candidate tracks: 1017

# %%
def saving_function(ids, csv_file_path):
    '''
    Appends new track IDs to a CSV file, ensuring no duplicates.
    '''
    try:
        # Check if the CSV file exists and read it
        existing_data = pd.read_csv(csv_file_path)
        existing_ids = set(existing_data['track_id'].tolist())
    except FileNotFoundError:
        # File does not exist, create an empty set
        existing_ids = set()

    # Convert id_tracks to a set for efficient comparison
    new_ids_set = set(ids)

    # Find new IDs that are not in the existing data
    new_ids_to_append = new_ids_set - existing_ids

    if new_ids_to_append:
        # Append new data and save
        new_data = pd.DataFrame({'track_id': list(new_ids_to_append)})
        new_data.to_csv(csv_file_path, mode='a', header=not existing_ids, index=False)
        print(f"Appended new data to the CSV file at {csv_file_path}")
    else:
        print("No new data to append.")

name= 'id_tracks'
saving_function(id_tracks, f'./data/{name}.csv')
# Out:
# Appended new data to the CSV file at ./data/id_tracks.csv

# %%
import os
import pickle
import pandas as pd
import time

def get_track_details_and_features(sp, id_tracks, CACHE_DIR='./spotify_data_cache', CACHE_FILE='track_features_cache.pickle'):
    '''
    Retrieves track details and audio features for each track in 'id_tracks' using Spotify client 'sp'.
    Utilizes a pickle file for caching and includes error handling for rate limits.
    Returns a DataFrame with track names and features.
    '''

    os.makedirs(CACHE_DIR, exist_ok=True)
    cache_file_path = os.path.join(CACHE_DIR, CACHE_FILE)

    if os.path.exists(cache_file_path):
        with open(cache_file_path, 'rb') as file:
            cached_data = pickle.load(file)
    else:
        cached_data = {}

    track_names = []
    features = []
    ntracks = len(id_tracks)

    for i, track_id in enumerate(id_tracks):
        # print(f'Processing track {i+1} of {ntracks}...')

        if track_id not in cached_data:
            track_details = sp.track(track_id)
            track_name = track_details['name']
            print(track_name)
            audio_features = sp.audio_features(track_id)

            if audio_features[0] is not None:
                cached_data[track_id] = {'name': track_name, 'features': audio_features[0]}
                with open(cache_file_path, 'wb') as file:
                    pickle.dump(cached_data, file)

            time.sleep(1)  # Adds a 1-second delay to avoid rate limits

        if track_id in cached_data:
            track_names.append(cached_data[track_id]['name'])
            features.append(cached_data[track_id]['features'])

    print('Done!')
    candidates_df = pd.DataFrame(features, index=track_names)
    
    candidates_clean = cleaning_df(candidates_df)

    csv_file_path = './spotify_data_cache/candidates.csv'
    if os.path.exists(csv_file_path):
        existing_data = pd.read_csv(csv_file_path)
        updated_data = pd.concat([existing_data, candidates_clean]).drop_duplicates()
    else:
        updated_data = candidates_clean

    updated_data.to_csv(csv_file_path, index=False)
    print("CSV file updated.")

    return updated_data

# %%
updated_data  = get_track_details_and_features(sp, id_tracks)
# Out:
# Processing track 1 of 1017...
# Processing track 2 of 1017...
# Processing track 3 of 1017...
# Processing track 4 of 1017...
# Processing track 5 of 1017...
# Processing track 6 of 1017...
# Processing track 7 of 1017...
# Processing track 8 of 1017...
# Processing track 9 of 1017...
# Processing track 10 of 1017...
# Processing track 11 of 1017...
# Processing track 12 of 1017...
# Processing track 13 of 1017...
# Processing track 14 of 1017...
# Processing track 15 of 1017...
# Processing track 16 of 1017...
# Processing track 17 of 1017...
# Processing track 18 of 1017...
# Processing track 19 of 1017...
# Processing track 20 of 1017...
# Processing track 21 of 1017...
# Processing track 22 of 1017...
# Processing track 23 of 1017...
# Processing track 24 of 1017...
# Processing track 25 of 1017...
# Processing track 26 of 1017...
# Processing track 27 of 1017...
# Processing track 28 of 1017...
# Processing track 29 of 1017...
# Processing track 30 of 1017...
# Processing track 31 of 1017...
# Processing track 32 of 1017...
# Processing track 33 of 1017...
# Processing track 34 of 1017...
# Processing track 35 of 1017...
# Processing track 36 of 1017...
# Processing track 37 of 1017...
# Processing track 38 of 1017...
# Processing track 39 of 1017...
# Processing track 40 of 1017...
# Processing track 41 of 1017...
# Processing track 42 of 1017...
# Processing track 43 of 1017...
# Processing track 44 of 1017...
# Processing track 45 of 1017...
# Processing track 46 of 1017...
# Processing track 47 of 1017...
# Processing track 48 of 1017...
# Processing track 49 of 1017...
# Processing track 50 of 1017...
# Processing track 51 of 1017...
# Processing track 52 of 1017...
# Processing track 53 of 1017...
# Processing track 54 of 1017...
# Processing track 55 of 1017...
# Processing track 56 of 1017...
# Processing track 57 of 1017...
# Processing track 58 of 1017...
# Processing track 59 of 1017...
# Processing track 60 of 1017...
# Processing track 61 of 1017...
# Processing track 62 of 1017...
# Processing track 63 of 1017...
# Processing track 64 of 1017...
# Processing track 65 of 1017...
# Processing track 66 of 1017...
# Processing track 67 of 1017...
# Processing track 68 of 1017...
# Processing track 69 of 1017...
# Processing track 70 of 1017...
# Processing track 71 of 1017...
# Processing track 72 of 1017...
# Processing track 73 of 1017...
# Processing track 74 of 1017...
# Processing track 75 of 1017...
# Processing track 76 of 1017...
# Processing track 77 of 1017...
# Processing track 78 of 1017...
# Processing track 79 of 1017...
# Processing track 80 of 1017...
# Processing track 81 of 1017...
# Processing track 82 of 1017...
# Processing track 83 of 1017...
# Processing track 84 of 1017...
# Processing track 85 of 1017...
# Processing track 86 of 1017...
# Processing track 87 of 1017...
# Processing track 88 of 1017...
# Processing track 89 of 1017...
# Processing track 90 of 1017...
# Processing track 91 of 1017...
# Processing track 92 of 1017...
# Processing track 93 of 1017...
# Processing track 94 of 1017...
# Processing track 95 of 1017...
# Processing track 96 of 1017...
# Processing track 97 of 1017...
# Processing track 98 of 1017...
# Processing track 99 of 1017...
# Processing track 100 of 1017...
# Processing track 101 of 1017...
# Processing track 102 of 1017...
# Processing track 103 of 1017...
# Processing track 104 of 1017...
# Processing track 105 of 1017...
# Processing track 106 of 1017...
# Processing track 107 of 1017...
# Processing track 108 of 1017...
# Processing track 109 of 1017...
# Processing track 110 of 1017...
# Processing track 111 of 1017...
# Processing track 112 of 1017...
# Processing track 113 of 1017...
# Processing track 114 of 1017...
# Processing track 115 of 1017...
# Processing track 116 of 1017...
# Processing track 117 of 1017...
# Processing track 118 of 1017...
# Processing track 119 of 1017...
# Processing track 120 of 1017...
# Processing track 121 of 1017...
# Processing track 122 of 1017...
# Processing track 123 of 1017...
# Processing track 124 of 1017...
# Processing track 125 of 1017...
# Processing track 126 of 1017...
# Processing track 127 of 1017...
# Processing track 128 of 1017...
# Processing track 129 of 1017...
# Processing track 130 of 1017...
# Processing track 131 of 1017...
# Processing track 132 of 1017...
# Processing track 133 of 1017...
# Processing track 134 of 1017...
# Processing track 135 of 1017...
# Processing track 136 of 1017...
# Processing track 137 of 1017...
# Processing track 138 of 1017...
# Processing track 139 of 1017...
# Processing track 140 of 1017...
# Processing track 141 of 1017...
# Processing track 142 of 1017...
# Processing track 143 of 1017...
# Processing track 144 of 1017...
# Processing track 145 of 1017...
# Processing track 146 of 1017...
# Processing track 147 of 1017...
# Processing track 148 of 1017...
# Processing track 149 of 1017...
# Processing track 150 of 1017...
# Processing track 151 of 1017...
# Processing track 152 of 1017...
# Processing track 153 of 1017...
# Processing track 154 of 1017...
# Processing track 155 of 1017...
# Processing track 156 of 1017...
# Processing track 157 of 1017...
# Processing track 158 of 1017...
# Processing track 159 of 1017...
# Processing track 160 of 1017...
# Processing track 161 of 1017...
# Processing track 162 of 1017...
# Processing track 163 of 1017...
# Processing track 164 of 1017...
# Processing track 165 of 1017...
# Processing track 166 of 1017...
# Processing track 167 of 1017...
# Processing track 168 of 1017...
# Processing track 169 of 1017...
# Processing track 170 of 1017...
# Processing track 171 of 1017...
# Processing track 172 of 1017...
# Processing track 173 of 1017...
# Processing track 174 of 1017...
# Processing track 175 of 1017...
# Processing track 176 of 1017...
# Processing track 177 of 1017...
# Processing track 178 of 1017...
# Processing track 179 of 1017...
# Processing track 180 of 1017...
# Processing track 181 of 1017...
# Processing track 182 of 1017...
# Processing track 183 of 1017...
# Processing track 184 of 1017...
# Processing track 185 of 1017...
# Processing track 186 of 1017...
# Processing track 187 of 1017...
# Processing track 188 of 1017...
# Processing track 189 of 1017...
# Processing track 190 of 1017...
# Processing track 191 of 1017...
# Processing track 192 of 1017...
# Processing track 193 of 1017...
# Processing track 194 of 1017...
# Processing track 195 of 1017...
# Processing track 196 of 1017...
# Processing track 197 of 1017...
# Processing track 198 of 1017...
# Processing track 199 of 1017...
# Processing track 200 of 1017...
# Processing track 201 of 1017...
# Processing track 202 of 1017...
# Processing track 203 of 1017...
# Processing track 204 of 1017...
# Processing track 205 of 1017...
# Processing track 206 of 1017...
# Processing track 207 of 1017...
# Processing track 208 of 1017...
# Processing track 209 of 1017...
# Processing track 210 of 1017...
# Processing track 211 of 1017...
# Processing track 212 of 1017...
# Processing track 213 of 1017...
# Processing track 214 of 1017...
# Processing track 215 of 1017...
# Processing track 216 of 1017...
# Processing track 217 of 1017...
# Processing track 218 of 1017...
# Processing track 219 of 1017...
# Processing track 220 of 1017...
# Processing track 221 of 1017...
# Processing track 222 of 1017...
# Processing track 223 of 1017...
# Processing track 224 of 1017...
# Processing track 225 of 1017...
# Processing track 226 of 1017...
# Processing track 227 of 1017...
# Processing track 228 of 1017...
# Processing track 229 of 1017...
# Processing track 230 of 1017...
# Processing track 231 of 1017...
# Processing track 232 of 1017...
# Processing track 233 of 1017...
# Processing track 234 of 1017...
# Processing track 235 of 1017...
# Processing track 236 of 1017...
# Processing track 237 of 1017...
# Processing track 238 of 1017...
# Processing track 239 of 1017...
# Processing track 240 of 1017...
# Processing track 241 of 1017...
# Processing track 242 of 1017...
# Processing track 243 of 1017...
# Processing track 244 of 1017...
# Processing track 245 of 1017...
# Processing track 246 of 1017...
# Processing track 247 of 1017...
# Processing track 248 of 1017...
# Processing track 249 of 1017...
# Processing track 250 of 1017...
# Processing track 251 of 1017...
# Processing track 252 of 1017...
# Processing track 253 of 1017...
# Processing track 254 of 1017...
# Processing track 255 of 1017...
# Processing track 256 of 1017...
# Processing track 257 of 1017...
# Processing track 258 of 1017...
# Processing track 259 of 1017...
# Processing track 260 of 1017...
# Processing track 261 of 1017...
# Processing track 262 of 1017...
# Processing track 263 of 1017...
# Processing track 264 of 1017...
# Processing track 265 of 1017...
# Processing track 266 of 1017...
# Processing track 267 of 1017...
# Processing track 268 of 1017...
# Processing track 269 of 1017...
# Processing track 270 of 1017...
# Processing track 271 of 1017...
# Processing track 272 of 1017...
# Processing track 273 of 1017...
# Processing track 274 of 1017...
# Processing track 275 of 1017...
# Processing track 276 of 1017...
# Processing track 277 of 1017...
# Processing track 278 of 1017...
# Processing track 279 of 1017...
# Processing track 280 of 1017...
# Processing track 281 of 1017...
# Processing track 282 of 1017...
# Processing track 283 of 1017...
# Processing track 284 of 1017...
# Processing track 285 of 1017...
# Processing track 286 of 1017...
# Processing track 287 of 1017...
# Processing track 288 of 1017...
# Processing track 289 of 1017...
# Processing track 290 of 1017...
# Processing track 291 of 1017...
# Processing track 292 of 1017...
# Processing track 293 of 1017...
# Processing track 294 of 1017...
# Processing track 295 of 1017...
# Processing track 296 of 1017...
# Processing track 297 of 1017...
# Processing track 298 of 1017...
# Processing track 299 of 1017...
# Processing track 300 of 1017...
# Processing track 301 of 1017...
# Processing track 302 of 1017...
# Processing track 303 of 1017...
# Processing track 304 of 1017...
# Processing track 305 of 1017...
# Processing track 306 of 1017...
# Processing track 307 of 1017...
# Processing track 308 of 1017...
# Processing track 309 of 1017...
# Processing track 310 of 1017...
# Processing track 311 of 1017...
# Processing track 312 of 1017...
# Processing track 313 of 1017...
# Processing track 314 of 1017...
# Processing track 315 of 1017...
# Processing track 316 of 1017...
# Processing track 317 of 1017...
# Processing track 318 of 1017...
# Processing track 319 of 1017...
# Processing track 320 of 1017...
# Processing track 321 of 1017...
# Processing track 322 of 1017...
# Processing track 323 of 1017...
# Processing track 324 of 1017...
# Processing track 325 of 1017...
# Processing track 326 of 1017...
# Processing track 327 of 1017...
# Processing track 328 of 1017...
# Processing track 329 of 1017...
# Processing track 330 of 1017...
# Processing track 331 of 1017...
# Processing track 332 of 1017...
# Processing track 333 of 1017...
# Processing track 334 of 1017...
# Processing track 335 of 1017...
# Processing track 336 of 1017...
# Processing track 337 of 1017...
# Processing track 338 of 1017...
# Processing track 339 of 1017...
# Processing track 340 of 1017...
# Processing track 341 of 1017...
# Processing track 342 of 1017...
# Processing track 343 of 1017...
# Processing track 344 of 1017...
# Processing track 345 of 1017...
# Processing track 346 of 1017...
# Processing track 347 of 1017...
# Processing track 348 of 1017...
# Processing track 349 of 1017...
# Processing track 350 of 1017...
# Processing track 351 of 1017...
# Processing track 352 of 1017...
# Processing track 353 of 1017...
# Processing track 354 of 1017...
# Processing track 355 of 1017...
# Processing track 356 of 1017...
# Processing track 357 of 1017...
# Processing track 358 of 1017...
# Processing track 359 of 1017...
# Processing track 360 of 1017...
# Processing track 361 of 1017...
# Processing track 362 of 1017...
# Processing track 363 of 1017...
# Processing track 364 of 1017...
# Processing track 365 of 1017...
# Processing track 366 of 1017...
# Processing track 367 of 1017...
# Processing track 368 of 1017...
# Processing track 369 of 1017...
# Processing track 370 of 1017...
# Processing track 371 of 1017...
# Processing track 372 of 1017...
# Processing track 373 of 1017...
# Processing track 374 of 1017...
# Processing track 375 of 1017...
# Processing track 376 of 1017...
# Processing track 377 of 1017...
# Processing track 378 of 1017...
# Processing track 379 of 1017...
# Processing track 380 of 1017...
# Processing track 381 of 1017...
# Processing track 382 of 1017...
# Processing track 383 of 1017...
# Processing track 384 of 1017...
# Processing track 385 of 1017...
# Processing track 386 of 1017...
# Processing track 387 of 1017...
# Processing track 388 of 1017...
# Processing track 389 of 1017...
# Processing track 390 of 1017...
# Processing track 391 of 1017...
# Processing track 392 of 1017...
# Processing track 393 of 1017...
# Processing track 394 of 1017...
# Processing track 395 of 1017...
# Processing track 396 of 1017...
# Processing track 397 of 1017...
# Processing track 398 of 1017...
# Processing track 399 of 1017...
# Processing track 400 of 1017...
# Processing track 401 of 1017...
# Processing track 402 of 1017...
# Processing track 403 of 1017...
# Processing track 404 of 1017...
# Processing track 405 of 1017...
# Processing track 406 of 1017...
# Processing track 407 of 1017...
# Processing track 408 of 1017...
# Processing track 409 of 1017...
# Processing track 410 of 1017...
# Processing track 411 of 1017...
# Processing track 412 of 1017...
# Processing track 413 of 1017...
# Processing track 414 of 1017...
# Processing track 415 of 1017...
# Processing track 416 of 1017...
# Processing track 417 of 1017...
# Processing track 418 of 1017...
# Processing track 419 of 1017...
# Processing track 420 of 1017...
# Processing track 421 of 1017...
# Processing track 422 of 1017...
# Processing track 423 of 1017...
# Processing track 424 of 1017...
# Processing track 425 of 1017...
# Processing track 426 of 1017...
# Processing track 427 of 1017...
# Processing track 428 of 1017...
# Processing track 429 of 1017...
# Processing track 430 of 1017...
# Processing track 431 of 1017...
# Processing track 432 of 1017...
# Processing track 433 of 1017...
# Processing track 434 of 1017...
# Processing track 435 of 1017...
# Processing track 436 of 1017...
# Processing track 437 of 1017...
# Processing track 438 of 1017...
# Processing track 439 of 1017...
# Processing track 440 of 1017...
# Processing track 441 of 1017...
# Processing track 442 of 1017...
# Processing track 443 of 1017...
# Processing track 444 of 1017...
# Processing track 445 of 1017...
# Processing track 446 of 1017...
# Processing track 447 of 1017...
# Processing track 448 of 1017...
# Processing track 449 of 1017...
# Processing track 450 of 1017...
# Processing track 451 of 1017...
# Processing track 452 of 1017...
# Processing track 453 of 1017...
# Processing track 454 of 1017...
# Processing track 455 of 1017...
# Processing track 456 of 1017...
# Processing track 457 of 1017...
# Processing track 458 of 1017...
# Processing track 459 of 1017...
# Processing track 460 of 1017...
# Processing track 461 of 1017...
# Processing track 462 of 1017...
# Processing track 463 of 1017...
# Processing track 464 of 1017...
# Processing track 465 of 1017...
# Processing track 466 of 1017...
# Processing track 467 of 1017...
# Processing track 468 of 1017...
# Processing track 469 of 1017...
# Processing track 470 of 1017...
# Processing track 471 of 1017...
# Processing track 472 of 1017...
# Processing track 473 of 1017...
# Processing track 474 of 1017...
# Processing track 475 of 1017...
# Processing track 476 of 1017...
# Processing track 477 of 1017...
# Processing track 478 of 1017...
# Processing track 479 of 1017...
# Processing track 480 of 1017...
# Processing track 481 of 1017...
# Processing track 482 of 1017...
# Processing track 483 of 1017...
# Processing track 484 of 1017...
# Processing track 485 of 1017...
# Processing track 486 of 1017...
# Processing track 487 of 1017...
# Processing track 488 of 1017...
# Processing track 489 of 1017...
# Processing track 490 of 1017...
# Processing track 491 of 1017...
# Processing track 492 of 1017...
# Processing track 493 of 1017...
# Processing track 494 of 1017...
# Processing track 495 of 1017...
# Processing track 496 of 1017...
# Processing track 497 of 1017...
# Processing track 498 of 1017...
# Processing track 499 of 1017...
# Processing track 500 of 1017...
# Processing track 501 of 1017...
# Processing track 502 of 1017...
# Processing track 503 of 1017...
# Processing track 504 of 1017...
# Processing track 505 of 1017...
# Processing track 506 of 1017...
# Processing track 507 of 1017...
# Processing track 508 of 1017...
# Processing track 509 of 1017...
# Processing track 510 of 1017...
# Processing track 511 of 1017...
# Processing track 512 of 1017...
# Processing track 513 of 1017...
# Processing track 514 of 1017...
# Processing track 515 of 1017...
# Processing track 516 of 1017...
# Processing track 517 of 1017...
# Processing track 518 of 1017...
# Processing track 519 of 1017...
# Processing track 520 of 1017...
# Processing track 521 of 1017...
# Processing track 522 of 1017...
# Processing track 523 of 1017...
# Processing track 524 of 1017...
# Processing track 525 of 1017...
# Processing track 526 of 1017...
# Processing track 527 of 1017...
# Processing track 528 of 1017...
# Processing track 529 of 1017...
# Processing track 530 of 1017...
# Processing track 531 of 1017...
# Processing track 532 of 1017...
# Processing track 533 of 1017...
# Processing track 534 of 1017...
# Processing track 535 of 1017...
# Processing track 536 of 1017...
# Processing track 537 of 1017...
# Processing track 538 of 1017...
# Processing track 539 of 1017...
# Processing track 540 of 1017...
# Processing track 541 of 1017...
# Processing track 542 of 1017...
# Processing track 543 of 1017...
# Processing track 544 of 1017...
# Processing track 545 of 1017...
# Processing track 546 of 1017...
# Processing track 547 of 1017...
# Processing track 548 of 1017...
# Processing track 549 of 1017...
# Processing track 550 of 1017...
# Processing track 551 of 1017...
# Processing track 552 of 1017...
# Processing track 553 of 1017...
# Processing track 554 of 1017...
# Processing track 555 of 1017...
# Processing track 556 of 1017...
# Processing track 557 of 1017...
# Processing track 558 of 1017...
# Processing track 559 of 1017...
# Processing track 560 of 1017...
# Processing track 561 of 1017...
# Processing track 562 of 1017...
# Processing track 563 of 1017...
# Processing track 564 of 1017...
# Processing track 565 of 1017...
# Processing track 566 of 1017...
# Processing track 567 of 1017...
# Processing track 568 of 1017...
# Processing track 569 of 1017...
# Processing track 570 of 1017...
# Processing track 571 of 1017...
# Processing track 572 of 1017...
# Processing track 573 of 1017...
# Processing track 574 of 1017...
# Processing track 575 of 1017...
# Processing track 576 of 1017...
# Processing track 577 of 1017...
# Processing track 578 of 1017...
# Processing track 579 of 1017...
# Processing track 580 of 1017...
# Processing track 581 of 1017...
# Processing track 582 of 1017...
# Processing track 583 of 1017...
# Processing track 584 of 1017...
# Processing track 585 of 1017...
# Processing track 586 of 1017...
# Processing track 587 of 1017...
# Processing track 588 of 1017...
# Processing track 589 of 1017...
# Processing track 590 of 1017...
# Processing track 591 of 1017...
# Processing track 592 of 1017...
# Processing track 593 of 1017...
# Processing track 594 of 1017...
# Processing track 595 of 1017...
# Processing track 596 of 1017...
# Processing track 597 of 1017...
# Processing track 598 of 1017...
# Processing track 599 of 1017...
# Processing track 600 of 1017...
# Processing track 601 of 1017...
# Processing track 602 of 1017...
# Processing track 603 of 1017...
# Processing track 604 of 1017...
# Processing track 605 of 1017...
# Processing track 606 of 1017...
# Processing track 607 of 1017...
# Processing track 608 of 1017...
# Processing track 609 of 1017...
# Processing track 610 of 1017...
# Processing track 611 of 1017...
# Processing track 612 of 1017...
# Processing track 613 of 1017...
# Processing track 614 of 1017...
# Processing track 615 of 1017...
# Processing track 616 of 1017...
# Processing track 617 of 1017...
# Processing track 618 of 1017...
# Processing track 619 of 1017...
# Processing track 620 of 1017...
# Processing track 621 of 1017...
# Processing track 622 of 1017...
# Processing track 623 of 1017...
# Processing track 624 of 1017...
# Processing track 625 of 1017...
# Processing track 626 of 1017...
# Processing track 627 of 1017...
# Processing track 628 of 1017...
# Processing track 629 of 1017...
# Processing track 630 of 1017...
# Processing track 631 of 1017...
# Processing track 632 of 1017...
# Processing track 633 of 1017...
# Processing track 634 of 1017...
# Processing track 635 of 1017...
# Processing track 636 of 1017...
# Processing track 637 of 1017...
# Processing track 638 of 1017...
# Processing track 639 of 1017...
# Processing track 640 of 1017...
# Processing track 641 of 1017...
# Processing track 642 of 1017...
# Processing track 643 of 1017...
# Processing track 644 of 1017...
# Processing track 645 of 1017...
# Processing track 646 of 1017...
# Processing track 647 of 1017...
# Processing track 648 of 1017...
# Processing track 649 of 1017...
# Processing track 650 of 1017...
# Processing track 651 of 1017...
# Processing track 652 of 1017...
# Processing track 653 of 1017...
# Processing track 654 of 1017...
# Processing track 655 of 1017...
# Processing track 656 of 1017...
# Processing track 657 of 1017...
# Processing track 658 of 1017...
# Processing track 659 of 1017...
# Processing track 660 of 1017...
# Processing track 661 of 1017...
# Processing track 662 of 1017...
# Processing track 663 of 1017...
# Processing track 664 of 1017...
# Processing track 665 of 1017...
# ERROR:spotipy.client:Max Retries reached
# ---------------------------------------------------------------------------
# MaxRetryError                             Traceback (most recent call last)
# File c:\Users\Felix\miniconda3\envs\ironhack\Lib\site-packages\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#
# File c:\Users\Felix\miniconda3\envs\ironhack\Lib\site-packages\urllib3\connectionpool.py:889, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     888     log.debug("Retry: %s", url)
# --> 889     return self.urlopen(
#     890         method,
#     891         url,
#     892         body,
#     893         headers,
#     894         retries=retries,
#     895         redirect=redirect,
#     896         assert_same_host=assert_same_host,
#     897         timeout=timeout,
#     898         pool_timeout=pool_timeout,
#     899         release_conn=release_conn,
#     900         chunked=chunked,
#     901         body_pos=body_pos,
#     902         **response_kw
#     903     )
#     905 return response
#
# File c:\Users\Felix\miniconda3\envs\ironhack\Lib\site-packages\urllib3\connectionpool.py:889, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     888     log.debug("Retry: %s", url)
# --> 889     return self.urlopen(
#     890         method,
#     891         url,
#     892         body,
#     893         headers,
#     894         retries=retries,
#     895         redirect=redirect,
#     896         assert_same_host=assert_same_host,
#     897         timeout=timeout,
#     898         pool_timeout=pool_timeout,
#     899         release_conn=release_conn,
#     900         chunked=chunked,
#     901         body_pos=body_pos,
#     902         **response_kw
#     903     )
#     905 return response
#
# File c:\Users\Felix\miniconda3\envs\ironhack\Lib\site-packages\urllib3\connectionpool.py:889, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     888     log.debug("Retry: %s", url)
# --> 889     return self.urlopen(
#     890         method,
#     891         url,
#     892         body,
#     893         headers,
#     894         retries=retries,
#     895         redirect=redirect,
#     896         assert_same_host=assert_same_host,
#     897         timeout=timeout,
#     898         pool_timeout=pool_timeout,
#     899         release_conn=release_conn,
#     900         chunked=chunked,
#     901         body_pos=body_pos,
#     902         **response_kw
#     903     )
#     905 return response
#
# File c:\Users\Felix\miniconda3\envs\ironhack\Lib\site-packages\urllib3\connectionpool.py:879, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     878 try:
# --> 879     retries = retries.increment(method, url, response=response, _pool=self)
#     880 except MaxRetryError:
#
# File c:\Users\Felix\miniconda3\envs\ironhack\Lib\site-packages\urllib3\util\retry.py:592, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     591 if new_retry.is_exhausted():
# --> 592     raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     594 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='api.spotify.com', port=443): Max retries exceeded with url: /v1/audio-features/?ids=0EsxDFcoqQHBUNAQhzWyHX (Caused by ResponseError('too many 429 error responses'))
#
# During handling of the above exception, another exception occurred:
#
# RetryError                                Traceback (most recent call last)
# File c:\Users\Felix\miniconda3\envs\ironhack\Lib\site-packages\spotipy\client.py:266, in Spotify._internal_call(self, method, url, payload, params)
#     265 try:
# --> 266     response = self._session.request(
#     267         method, url, headers=headers, proxies=self.proxies,
#     268         timeout=self.requests_timeout, **args
#     269     )
#     271     response.raise_for_status()
#
# File c:\Users\Felix\miniconda3\envs\ironhack\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\Felix\miniconda3\envs\ironhack\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#
# File c:\Users\Felix\miniconda3\envs\ironhack\Lib\site-packages\requests\adapters.py:510, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     509 if isinstance(e.reason, ResponseError):
# --> 510     raise RetryError(e, request=request)
#     512 if isinstance(e.reason, _ProxyError):
#
# RetryError: HTTPSConnectionPool(host='api.spotify.com', port=443): Max retries exceeded with url: /v1/audio-features/?ids=0EsxDFcoqQHBUNAQhzWyHX (Caused by ResponseError('too many 429 error responses'))
#
# During handling of the above exception, another exception occurred:
#
# SpotifyException                          Traceback (most recent call last)
# c:\Users\Felix\Documents\Ironhack\Projects\spotify_recommender\Intentando_encapsular.ipynb Cell 30 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Felix/Documents/Ironhack/Projects/spotify_recommender/Intentando_encapsular.ipynb#X41sZmlsZQ%3D%3D?line=0'>1</a> updated_data  = get_track_details_and_features(sp, id_tracks)
#
# c:\Users\Felix\Documents\Ironhack\Projects\spotify_recommender\Intentando_encapsular.ipynb Cell 30 line 3
#      <a href='vscode-notebook-cell:/c%3A/Users/Felix/Documents/Ironhack/Projects/spotify_recommender/Intentando_encapsular.ipynb#X41sZmlsZQ%3D%3D?line=29'>30</a> track_details = sp.track(track_id)
#      <a href='vscode-notebook-cell:/c%3A/Users/Felix/Documents/Ironhack/Projects/spotify_recommender/Intentando_encapsular.ipynb#X41sZmlsZQ%3D%3D?line=30'>31</a> track_name = track_details['name']
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Felix/Documents/Ironhack/Projects/spotify_recommender/Intentando_encapsular.ipynb#X41sZmlsZQ%3D%3D?line=31'>32</a> audio_features = sp.audio_features(track_id)
#      <a href='vscode-notebook-cell:/c%3A/Users/Felix/Documents/Ironhack/Projects/spotify_recommender/Intentando_encapsular.ipynb#X41sZmlsZQ%3D%3D?line=33'>34</a> if audio_features[0] is not None:
#      <a href='vscode-notebook-cell:/c%3A/Users/Felix/Documents/Ironhack/Projects/spotify_recommender/Intentando_encapsular.ipynb#X41sZmlsZQ%3D%3D?line=34'>35</a>     cached_data[track_id] = {'name': track_name, 'features': audio_features[0]}
#
# File c:\Users\Felix\miniconda3\envs\ironhack\Lib\site-packages\spotipy\client.py:1734, in Spotify.audio_features(self, tracks)
#    1732 if isinstance(tracks, str):
#    1733     trackid = self._get_id("track", tracks)
# -> 1734     results = self._get("audio-features/?ids=" + trackid)
#    1735 else:
#    1736     tlist = [self._get_id("track", t) for t in tracks]
#
# File c:\Users\Felix\miniconda3\envs\ironhack\Lib\site-packages\spotipy\client.py:323, in Spotify._get(self, url, args, payload, **kwargs)
#     320 if args:
#     321     kwargs.update(args)
# --> 323 return self._internal_call("GET", url, payload, kwargs)
#
# File c:\Users\Felix\miniconda3\envs\ironhack\Lib\site-packages\spotipy\client.py:307, in Spotify._internal_call(self, method, url, payload, params)
#     305     except (IndexError, AttributeError):
#     306         reason = None
# --> 307     raise SpotifyException(
#     308         429,
#     309         -1,
#     310         "%s:\n %s" % (request.path_url, "Max Retries"),
#     311         reason=reason
#     312     )
#     313 except ValueError:
#     314     results = None
#
# SpotifyException: http status: 429, code:-1 - /v1/audio-features/?ids=0EsxDFcoqQHBUNAQhzWyHX:
#  Max Retries, reason: too many 429 error responses

# %%
name = 'candidates'
saving_function(updated_data, f'./data/{name}.csv')

# %%
'''Calling the cleaning function to apply to the dataset'''

candidates = cleaning_df(updated_data)

# %%
top_tracks_clean_mtx = top_tracks_clean.iloc[:,1:].values
candidatos_mtx = candidates.iloc[:,1:].values

# %%
scaler = StandardScaler()
t20_scaled = scaler.fit_transform(top_tracks_clean_mtx)
can_scaled = scaler.fit_transform(candidatos_mtx)
t20_norm = np.sqrt((t20_scaled*t20_scaled).sum(axis=1))
can_norm = np.sqrt((can_scaled*can_scaled).sum(axis=1))
nt20 = t20_scaled.shape[0]
ncan = can_scaled.shape[0]
t20 = t20_scaled/t20_norm.reshape(nt20,1)
can = can_scaled/can_norm.reshape(ncan,1)
cos_sim = linear_kernel(t20,can)
cos_sim.shape
# Out:
# (20, 398)

# %%
def obtener_candidatos(pos, cos_sim, ncands, umbral = 0.5):
    
    # Obtener todas las pistas candidatas por encima de umbral
    
    idx = np.where(cos_sim[pos,:]>=umbral)[0] 
    
    # Y organizarlas de forma descendente (por similitudes de mayor a menor)
    idx = idx[np.argsort(cos_sim[pos,idx])[::-1]] # [::-1] porque por defecto argsort organiza de manera ascendente

    # Si hay más de "ncands", retornar máximo "ncands"
    if len(idx) >= ncands:
        cands = idx[0:ncands]
    else:
        cands = idx
  
    return cands

# %%
ids_t20 = []
ids_playlist = []

for i in range(top_tracks_clean.shape[0]):
    print(top_tracks_clean.index[i])   
    ids_t20.append(top_tracks_clean['id'][i])
    
    # Obtener listado de candidatos para esta pista
    cands = obtener_candidatos(i, cos_sim, 5, umbral=0.8)
    
    # Si hay pistas relacionadas obtener los ids correspondientes
    # e imprimir en pantalla
    if len(cands)==0:
        print('     ***No se encontraron pistas relacionadas***')
    else:
        # Obtener los ids correspondientes e imprimir en pantalla
        for j in cands:
            id_cand = candidates['id'][j]
            ids_playlist.append(id_cand)
            
            print(f'   {candidates.index[j]}')
# Out:
# Si No Estás
#    Maldita
#    Hermosa Flor - Live
#    Parte de Mí
#    Sin Avisar
#    Hope You're Proud
# QLONA
#    ENIGMA
# Fire On Fire
#    Start
# MI EX TENÍA RAZÓN
#    Gladiador
# Tamagotchi
#      ***No se encontraron pistas relacionadas***
# LALA
#      ***No se encontraron pistas relacionadas***
# Sin Tiempo Para Bailar
#    Sin Tiempo Para Bailar
#    Sin Tiempo Para Bailar
#    CELEBRÉ
#    Virginia Beach
#    Virginia Beach
# greedy
#      ***No se encontraron pistas relacionadas***
# Hey Mor
#      ***No se encontraron pistas relacionadas***
# AMARGURA
#    Queriéndote
#    Queriéndote
#    Más Fuerte
# In The Stars
#    Movies
#    Mil y una noches
#    Música para bailar sobre el agua
#    ATM
# PERRO NEGRO
#      ***No se encontraron pistas relacionadas***
# Según Quién
#    Peligrosa
#    It Is What It Is - Acoustic
#    Magnum
#    Apretaito
# WANDA
#    Gladiador
# Columbia
#    The Path
#    The Path
#    ATM
#    Qué Gano Olvidándote
# Sobredosis
#    hill that i'll die on
#    Sad Forever
#    MEDIA LUNA
#    Horizon - from One Night In Malibu
#    Intro - Prod. Jam City & el Guincho
# Déjala Que Vuelva (feat. Manuel Turizo)
#    Flowers
#    Heart Wants What It Wants
#    Clima Tropical
#    CHEMICALS
#    Big Dumb Heart
# BESO
#      ***No se encontraron pistas relacionadas***
# QLONA
#    ENIGMA
# Hasta Que Dios Diga
#      ***No se encontraron pistas relacionadas***
# C:\Users\Felix\AppData\Local\Temp\ipykernel_17116\3446160394.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   ids_t20.append(top_tracks_clean['id'][i])
# C:\Users\Felix\AppData\Local\Temp\ipykernel_17116\3446160394.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   id_cand = candidates['id'][j]

# %%
ids_playlist_dep = [x for x in ids_playlist if x not in ids_t20]
ids_playlist_dep = list(set(ids_playlist_dep))

# %%
ids_playlist_dep
# Out:
# ['6onjYVJaW2UMu3sGRzm0In',
#  '3eP13S8D5m2cweMEg3ZDed',
#  '69Api7PDVnQ1jQmSJlZiGC',
#  '4O6jCUU0Un55TZ9FfZWSJh',
#  '0Ckmi4rrdUWnlg4T9aIGCS',
#  '6FH6fmlh9DbvssuEQyQEVd',
#  '3AsbVi6XAEGXoKOTfhzevi',
#  '3T9wo7kdEAOy1h5h7kh5dw',
#  '4GoFt15vBKmQXqB3IfFzy7',
#  '1iPPvZimh7slFBPE3Oe4pe',
#  '3UunIIJTjCNhLkJ3HXzAAx',
#  '6PLihys6LLwbCI9GRByWZ0',
#  '0g8DBFUhszRFIUp6lSZIB4',
#  '2XMXsM29VG71gcKokMtsK5',
#  '5fDMDKHhVCpUmAvTPJrYNh',
#  '37DLwjAM682PZr9a4dJ5VA',
#  '3dG6YbDEyxKnIt0K8xYQSI',
#  '2sY92LRATo3fwPzmDo0wwt',
#  '5qf8lBMF49mfNILgF1TYTG',
#  '3qPZbR73DQm1ZNrkXvuJ4B',
#  '63jCeAYGLcRL21xm0jKlgn',
#  '1tNpEy5ETYG6GbqHSGrmU3',
#  '6YV2AI87l1n2fzqU8Dyo05',
#  '68C2QbQUPIoTLDFJPZppCX',
#  '7c8FD6rZJerQ1q1djZuQmA',
#  '0LFxsB0fdwNIjfUtVpvAmq',
#  '7DSAEUvxU8FajXtRloy8M0',
#  '7iXRsjttPa62GpOcqsx1aE',
#  '5Ov0CcRjy72vbMFJfyVX63',
#  '1HYM42YsijT5tqgJO3PKsn',
#  '7h3mCPlHYCPuSG93s7M3Xt',
#  '2B4u4howohJ8kbkWcbuAUM',
#  '5pdmo1nRKvuStKgtUXgJm5',
#  '7JqqIi2ktnsNkYdQhKSCrz']

# %%
pl = sp.user_playlist_create(user='niniet1998', 
                             name='Spotipy Recommender Playlist', 
                             description="Playlist created with the recommendation system")

sp.playlist_add_items(pl['id'],ids_playlist_dep)
# Out:
# {'snapshot_id': 'MyxiODE1MjI3OWMzNjdiYzFmMGNmYTJjYjFkYjFmZGE3NjNkZTM1ZmQ3'}
