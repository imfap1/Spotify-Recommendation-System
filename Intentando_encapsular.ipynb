# %%
import pickle
import json
import pandas as pd
import numpy as np

#-----------------------------------------------#

import requests
import threading
import time
import os
from dotenv import load_dotenv

#-----------------------------------------------#

from spotipy.oauth2 import SpotifyOAuth
import spotipy
import spotipy.util as util

#-----------------------------------------------#

from sklearn.preprocessing import StandardScaler
from sklearn.metrics.pairwise import linear_kernel

# %%
load_dotenv()
# Out:
# True

# %%
'''Setting up a directory for caching Spotify data and initializig Spotify API credentials and user details using environment variables. 
It prepares for connecting to the Spotify API by defining the cache directory, client ID, client secret, redirect URI, and username.'''

CACHE_DIR = './spotify_data_cache'
cid = os.getenv('SPOTIPY_CLIENT_ID')
secret = os.getenv('SPOTIPY_CLIENT_SECRET')
redirect_uri = 'http://localhost:8080'
username = os.getenv('USERNAME')

# %%
''' This code initializes Spotify API authorization with specific scopes for reading user's top tracks and modifying playlists'''

scope = 'user-top-read playlist-modify-public playlist-modify-private'
auth_manager = SpotifyOAuth(client_id=cid, client_secret=secret, redirect_uri=redirect_uri, scope=scope, username=username)
sp = spotipy.Spotify(auth_manager=auth_manager, requests_timeout=10)

# %%
def get_top_tracks(sp, time_range='short_term', limit=20):
    
    '''This function, get_top_tracks, retrieves a Spotify user's top tracks, utilizing caching to store and access the data efficiently. 
    It checks for cached data in a specified directory before making an API call, saving any new data retrieved for future use.'''
    
    cache_file_path = os.path.join(CACHE_DIR, 'all_top_tracks.json')

    if os.path.exists(cache_file_path):
        with open(cache_file_path, 'r') as cache_file:
            return json.load(cache_file)

    top_tracks = sp.current_user_top_tracks(time_range=time_range, limit=limit)

    with open(cache_file_path, 'w') as cache_file:
        json.dump(top_tracks, cache_file)

    return top_tracks

top_tracks = get_top_tracks(sp)

# %%
for i, item in enumerate(top_tracks['items']):
    print(i+1, item['name'], '//', item['artists'][0]['name'])
# Out:
# 1 Schatzi bitte - Dream DJ Team Mix // Bitschu Batschu
# 2 Another Love // Tom Odell
# 3 Schmetterling // Baby B3ns
# 4 Cherries // Layfullstop
# 5 No Hands (feat. Roscoe Dash & Wale) // Waka Flocka Flame
# 6 I Miss You // blink-182
# 7 The Rapture Pt.III // &ME
# 8 Haifischlaserknarre // Mausio
# 9 Good Guy // Frank Ocean
# 10 Put Your Records On // Corinne Bailey Rae
# 11 Palestine // Ali Bumaye
# 12 Mbappe // Eladio Carrion
# 13 Krustenf!cker // Mausio
# 14 Wir haben Spass und ihr nicht // Anna Ullrich
# 15 TABU. // Yung Yury
# 16 Frei sein // DREAM DJ TEAM
# 17 Mädchen auf dem Pferd // Luca-Dante Spadafora
# 18 Love Yuh Bad // Popcaan
# 19 Jorja Interlude // Drake
# 20 Bounce // Joose The Conqueror

# %%
def create_tracks_dataframe(sp, top_tracks):
    '''
    This function processes a list of Spotify track data, extracting each track's ID, 
    name, and audio features, and then compiles this information into a Pandas DataFrame. 
    The DataFrame is indexed by track names for easy reference and analysis. It utilizes caching 
    to store and access the audio features data efficiently.
    '''

    tracks = top_tracks['items']
    track_ids = []  
    track_names = []
    features = []

    for track in tracks:
        track_id = track['id']
        track_name = track['name']

        cache_file_path = os.path.join(CACHE_DIR, 'tracks_features.json')

        if os.path.exists(cache_file_path):
            with open(cache_file_path, 'r') as cache_file:
                audio_features = json.load(cache_file)
        else:
            audio_features = sp.audio_features(track_id)
            with open(cache_file_path, 'w') as cache_file:
                json.dump(audio_features, cache_file)

        track_ids.append(track_id)
        track_names.append(track_name)
        features.append(audio_features[0] if audio_features else None)
    
    top_tracks_df = pd.DataFrame(features, index=track_names)
    
    return top_tracks_df, track_ids

# %%
'''Calling the previues function to create the new dataframe'''

top_tracks_df, track_ids = create_tracks_dataframe(sp, top_tracks)

# %%
def cleaning_df(track):
    
    '''The function cleaning_df takes a DataFrame track as input and returns a cleaned version, 
    top_tracks_clean, which contains only selected columns.'''
    
    top_tracks_clean = track[['id', 'danceability',	'energy',	'key',	'loudness',	'mode',	'speechiness',	'acousticness',	'instrumentalness',	'liveness',	'valence',	'tempo', 'duration_ms']]
    return top_tracks_clean

# %%
'''Calling the cleaning function to apply to the dataset'''

top_tracks_clean = cleaning_df(top_tracks_df)

# %%
def getting_id_artists(df):
    '''
    This function processes a DataFrame that contain Spotify track data, 
    and extracts the IDs of artists from its 'items' column. It prints the IDs and names 
    of the artists, and returns a list of these artist IDs.
    '''

    ids_artists = []
    print('|| Artists in my top 20: ||')
    print('===========================')

    for item in df['items']:
        artist_id = item['artists'][0]['id']
        artist_name = item['artists'][0]['name']
        print(f'{artist_id}: {artist_name}')
        ids_artists.append(artist_id)

    return ids_artists

# %%
ids_artists = getting_id_artists(top_tracks)
# Out:
# || Artists in my top 20: ||
# ===========================
# 20sx3E16MRur3wr3T9lWrt: Bitschu Batschu
# 2txHhyCwHjUEpJjWrEyqyX: Tom Odell
# 0geGEoVXjWIz38cw8JcqVP: Baby B3ns
# 44KO1So8LqWGobs7xNCqe9: Layfullstop
# 6f4XkbvYlXMH0QgVRzW0sM: Waka Flocka Flame
# 6FBDaR13swtiWwGhX1WQsP: blink-182
# 5mIowAJMp7RKNheelruV5z: &ME
# 5yzLRjAu6ni4Bb3fQDED2q: Mausio
# 2h93pZq0e7k5yf4dywlkpM: Frank Ocean
# 29WzbAQtDnBJF09es0uddn: Corinne Bailey Rae
# 6hMNiBKUQFKpnZ7GTvLVZf: Ali Bumaye
# 5XJDexmWFLWOkjOEjOVX3e: Eladio Carrion
# 5yzLRjAu6ni4Bb3fQDED2q: Mausio
# 50KbwRJgMFxSmT50FamuDN: Anna Ullrich
# 7tzELpzPjTq26pa5FT9ykz: Yung Yury
# 78HKXj2z44JthdgoqT9ElL: DREAM DJ TEAM
# 6k9e4mFFVtEAAhGdvJBtqB: Luca-Dante Spadafora
# 62DmErcU7dqZbJaDqwsqzR: Popcaan
# 3TVXtAsR1Inumwj472S9r4: Drake
# 3er7r6Hdg1VJzFfI4iLPzL: Joose The Conqueror

# %%
""" This code converts the ids_artists list to a set to remove any repeated IDs and then back to a list, displaying the count of unique artists.
"""

ids_artists = list(set(ids_artists))
print(f'Number of artists (without repetitions): {len(ids_artists)}')
# Out:
# Number of artists (without repetitions): 19

# %%
def get_similar_artists(sp, ids_artists, CACHE_DIR, CACHE_FILE='all_similar_artists.pickle'):
    '''
    This function takes a Spotify client 'sp' and a list of artist IDs 'ids_artists', finds similar 
    artists for each artist in the list, and prints their IDs and names. It utilizes a single .pickle file 
    caching system to efficiently store and access this data for all artists. The function returns a list of the IDs 
    of these similar artists.
    '''

    print('Similar Artists:')
    print('=====================')

    cache_file = os.path.join(CACHE_DIR, CACHE_FILE)

    if os.path.exists(cache_file):
        with open(cache_file, 'rb') as file:
            all_similar_artists = pickle.load(file)
    else:
        all_similar_artists = {}

    ids_similar_artists = []

    for artist_id in ids_artists:
        if artist_id not in all_similar_artists:
            artists = sp.artist_related_artists(artist_id)['artists']
            all_similar_artists[artist_id] = artists
            with open(cache_file, 'wb') as file:
                pickle.dump(all_similar_artists, file)
        else:
            artists = all_similar_artists[artist_id]

        for item in artists:
            similar_artist_id = item['id']
            similar_artist_name = item['name']
            print(f'{similar_artist_id}: {similar_artist_name}')
            ids_similar_artists.append(similar_artist_id)
        
        time.sleep(1)
    return ids_similar_artists

# %%
'''Calling the get_similar_artists function to create a new list'''

ids_similar_artists = get_similar_artists(sp, ids_artists, CACHE_DIR)
# Out:
# Similar Artists:
# =====================
# 6z1cicLMt9XArxN10q7m8a: Travis Porter
# 0bfX8pF8kuHNCs57Ms4jZb: Roscoe Dash
# 5gCRApTajqwbnHHPbr2Fpi: Juicy J
# 23LbwefIODbyGdRbAz3urj: Yung Joc
# 6Ha4aES39QiVjR0L2lwuwq: Yo Gotti
# 5lHRUCqkQZCIWeX7xG4sYT: Rich Homie Quan
# 31HjiqargV4NAw4GZqUale: Ace Hood
# 5einkgXXrjhfYCyac1FANB: Lil Scrappy
# 3jksrX4oBklxR78ft8gv3j: Plies
# 6GMYJwaziB4ekv1Y6wCDWS: Soulja Boy
# 7Kp7SzuRuNiPFCy7JIwnLx: Ca$h Out
# 3ciRvbBIVz9fBoPbtSYq4x: Lil Jon & The East Side Boyz
# 35sCXuy5gN6Or69rZ9vqBs: Birdman
# 44PA0rCQXikgOWbfY7Fq7m: Ying Yang Twins
# 0I5HubncQ8E1MFZOlPDY4J: Trinidad James
# 3Y365ZqTf6fJ4ZcRnLKPGt: Gorilla Zoe
# 030sRm1rnXI9MeQ23pdax8: Boyz N Da Hood
# 7jFaoqWPhYLrKzjzlpXmUO: David Banner
# 2r8r62VGJKGi463aH1HJUZ: Kirko Bangz
# 0VKTLKamj4IH8OfQbUL0kq: Dem Franchize Boyz
# 4BxCuXFJrSWGi1KHcVqaU4: Kodaline
# 0gadJ2b9A4SKsB1RFkBb66: Passenger
# 4EzkuveR9pLvDVFNx6foYD: James Bay
# 4Ly0KABsxlx4fNj63zJTrF: Seafret
# 2WX2uTcsvV5OnS0inACecP: Birdy
# 10exVja0key0uqUkk6LJRT: Vance Joy
# 6AyATGg7mDgBlZ4N5uNog0: SYML
# 1AgxgADPuRIW1wyaA4OKcB: Tom Rosenthal
# 0MmnmsAuQKRFpo6vJElcaU: Amber Run
# 2FXC3k01G6Gw61bmprjgqS: Hozier
# 2ysnwxxNtSgbb9t1m2Ur4j: George Ezra
# 5schNIzWdI9gJ1QRK8SBnc: Ben Howard
# 7EQ0qTo7fWT7DPxmxtSYEc: Bastille
# 6QrQ7OrISRYIfS5mtacaw2: Jaymes Young
# 7z2avKuuiMAT4XZJFv8Rvh: Tom Walker
# 0MeLMJJcouYXCymQSHPn8g: Sleeping At Last
# 3QSQFmccmX81fWCUSPTS7y: Dean Lewis
# 16oZKvXb6WkQlVAjwo2Wbg: The Lumineers
# 4qWnlmXWuGv2TtuxtIWlJX: BANNERS
# 3w6zswp5THsSKYLICUbDTZ: Gabrielle Aplin
# 5mYWkDD4b1eM4ZjFq5axxs: Aidonia
# 0eezS9KmhdjGN436RdTIXu: Mavado
# 2Gzy8TYJ5xrEMDyUjZuDsK: Masicka
# 2LIAgeQ5NZurwixfoG3CWZ: Alkaline
# 3nwYsifpwrKmCIpw4i0HDW: Konshens
# 28UDeKu2FPrU0T7dpUiSGY: Dexta Daps
# 0mkixmQkcUeE6egKHW4ojh: Jah Vinci
# 0af5VM6xubf8EXKvoG35x6: Demarco
# 2yHxc12dEUiLXNeqUadxBh: Tommy Lee Sparta
# 2NUz5P42WqkxilbI8ocN76: Vybz Kartel
# 30hElzuHCZ1qzCl364SHma: Teejay
# 2T5FHRvBN0LYvlvDoU89dS: I-Octane
# 4RfTXjK9aiiIKDaKUHpL57: Busy Signal
# 1pcKqVZ7T90mJ2rKo9XWYV: jahmiel
# 351x2S7CduShTNvtzgkMl7: DING DONG
# 5Xi3NfsVBIEbaWVUfBTy39: Govana
# 1LKo6ZA3RNvKtLa6zDu32S: Kranium
# 0wEvWMQRqaXcgnrZv6KtyL: Spice
# 0IHg6uUuIes2nxFoT0otpr: Rygin King
# 1OFOShsIbhy1l5x73yuVyB: Shenseea
# 2loEsOijJ6XiGzWYFXMIRk: Adam Port
# 08jywfUS0hp8XYlYs0cvz8: Rampa
# 26WKgv73kRHD0gEDKD1i8j: Keinemusik
# 3bqBkAzdPwEDe1JUvb7ZeC: Guy Gerber
# 3AE5c8fBFJYdxXHCSXAyVx: Re.You
# 5muFO8VqYRCRW13EkvX564: Âme
# 5eJJoSS6weFQeI9AtNFLee: Denis Horvat
# 48LWLoeY0dhwaiX1FRsn72: Mind Against
# 0H1va9wyZWImoOV4euIBcr: Ivory (IT)
# 3ujc8l2JVYwGgAPU7KRRl3: Echonomist
# 5OvpF1A65DXs93M9NfPIjT: Patrice Bäumel
# 4wPR8PhvdOB0vksHMUWDZY: Trikk
# 26J5ZprV3p7jv4fHTmpXsB: Fur Coat
# 6RsLLSkSTcL4YrvgRcBTQd: Jimi Jules
# 7lzrNOBAdfH8f4nVAWbRfk: Eagles & Butterflies
# 02DWGcShQivFepRvGJ7xhB: Adriatique
# 04KmByEP6icXVY0PvJaMMp: Mano Le Tough
# 39RaU9BN81x3KBo299bwXs: Fideles
# 5kLzaeSHrmS7okc5XNE6lv: Butch
# 2JnkjHtuUjz83gkEx8QMS4: Adana Twins
# 7bvcQXJHkFiN1ppIN3q4fi: Joss Stone
# 4ylR3zwA0zaapAu94fktwa: Macy Gray
# 7Gf3LSwa5hh8Cjo60WhVjC: India.Arie
# 37NqXwtb6nIEqRt4EJSoIO: Duffy
# 2RP4pPHTXlQpDnO9LvR7Yt: Lianne La Havas
# 2Kx7MNY7cI1ENniW7vT30N: Norah Jones
# 6AVLthptCPhfrxlHadOBJD: Jill Scott
# 5zzrJD2jXrE9dZ1AklRFcL: KT Tunstall
# 2Mu5NfyYm8n5iTomuKAEHl: Ms. Lauryn Hill
# 7IfculRW2WXyzNQ8djX8WX: Erykah Badu
# 6jlWj6y00bMQt8XoKuCjyZ: Emily King
# 4hVcxmC7igpot32EzQf7IR: Amel Larrieux
# 6ueGR6SWhUJfvEhqkvMsVs: Janelle Monáe
# 73ZPfpfg1LBVvDEArK4l5B: Des'ree
# 5bepW5vcdRzheNc0F8lHJ5: Esperanza Spalding
# 2hWr3AjjKOCVmWcwvuT4uM: Angie Stone
# 0iOVhN3tnSvgDbcg25JoJb: Etta James
# 6g0Wah2YFtb1rFgKhUktlo: Raphael Saadiq
# 3UVRliakQfa1pMWIsNuiZ8: Musiq Soulchild
# 13saZpZnCDWOI9D4IJhp1f: Lily Allen
# 1a71mkqZC54WhePSbnq7RK: Majoe
# 6nHDuiu6PIpfWt6DswQHvL: Alpa Gun
# 5iJuniDT0LFzXnMoLI1YFV: Seyed
# 33Dtwad3snCG92mhmi17WM: Massiv
# 0PhLCUFEU30lqntUbYZjSt: Mosh36
# 5C5hEZzr3BmvYcIPfWMnnC: Savas
# 5hNRMsMMDlMIvEwu4UvjQO: Sinan-G
# 7gIB5TTgIpeomi15bpGx7S: Al Gear
# 4Mt1ci7cKg2DpDS5kJ5mHS: Animus
# 4NtCgQTnJh0sSI40PtVz1E: Baba Saad
# 2HdP7fpDiLWAvElYGg75gd: Hanybal
# 2TGFJ7H3NWGIxmrrxdOozF: Berlins Most Wanted
# 7GaMopkesD4KK9dNbgyO5D: Eko Fresh
# 7CqB6nNGQPcaEJ940E2x2r: RAF 3.0
# 08ao8gzTHBtNf5Laf9jjwR: King Khalil
# 1hMzMy5THp7jWnMRC0rU36: Nazar
# 64NNRZT3lIEnaavebMacBw: Jasko
# 7iZ5x5fwRwROoX3iRWpVgN: Fard
# 6AZfDB8isLU2sHkSm3sRhX: Milonair
# 0o0PoOOyXcmqcyVz8aSdYu: Moe Phoenix
# 7IcGdAsWN9lAaQuvtntplr: Roots Raddix
# 1e0tqQ7fA1U2XcVMhCxvCM: Free Wize Men
# 2v3z0sSTauju6TA1GMqiQj: KinKai
# 4QEJclVyfANWhOEMZxNfTB: Berry Blacc
# 7BWjWVat8puiUriWads4kk: [ K S R ]
# 2UZjIISzcezFJLo0ngik2Z: Children of Zeus
# 0OfSZATpFGEwaoegGWHbqw: Cul Dé Sac
# 7yCdWDEm9XhixEPUKPnB75: Blind Mic
# 0eOlWPcqRSIbrJ1i9ESFhz: Hemai
# 0XAonyGKenXLN78RnyD44i: Abnormal Sleepz
# 0IKVDL3N8vpYgeNOV6np14: Lex Amor
# 2cOj9uwYqm3PHx1i5n7BkC: BINA.
# 30SZetOBMEael27tboxz7f: Emmavie
# 7ANeFdhioipksT9lqg0Ay6: Ego Ella May
# 4s5UfoEXxjyyjVZqqb1lrd: KEYAH/BLU
# 7C7k2UEHadhnuwaiN4TSdU: Black Josh
# 3fcW2V4zOfFm0IsWCJUuzz: Zilo
# 6FAh9D4OdyiBapKd1tsb5f: Akemi Fox
# 67JKY7pT71XLDPTNtUPZma: Voodoo Black
# 2d8cMSPIFolHyxuox8ESfm: NAYANA IZ
# 75c3TOrBX0IkcuGVGNybJl: The Seventh
# 0QyJDdX61vOFda8pXrgp0g: Waldo
# 1Z4kMiUwBM1dkoO6TyXXhn: Savon
# 5BLrsIX3Uipmt9QAiZGYEl: Myke Bogan
# 1KW04GdOuzrsTVOAVd6eRg: Jimi Tents
# 5PFRCnuYH5WA9guxIyca2A: Mozaic-AGO
# 21NrnXKmcu8PF48F8SwulJ: Jonah Cruzz
# 207WozQ2u38q4rRu9quqMU: Marcellus Juvann
# 51YACffgZvQwjs8J4ZVDQF: Warm Brew
# 2ID5ZEW2EbdUo1oEjwJnD3: Dot Demo
# 0JuDxOwz1e3Wx05t8e3AT3: Sylvan LaCue
# 2POqOOLcEH30IODCaW1Ytw: Michael Da Vinci
# 196ebGsn5Q6i5ctZtDgCXK: Siimbiie Lakew
# 1CEHZJXMMoOad9m7AjvcIZ: Stro
# 1MlV4b7HGi4AiZWXholyVu: IshDARR
# 0JdGPxHeRGfOyZg3EHwp2g: Alex Wiley
# 5rrxxBH8akTUOqowzf5bC4: Max Wonders
# 2c8n0uEGtZxolOWtE1dySR: Kyle Bent
# 2TLYSzGyVYkxAgYSCqUnQj: Jay Prince
# 0LHzh8WdqxdtnTzp0XIOyZ: WELL$
# 0Q8NcsJwoCbZOHHW63su5S: Mora
# 4aSlfXDn9R60UlbZEboBUy: YOVNGCHIMI
# 6nVcHLIgY5pE2YCl8ubca1: Jhayco
# 2YRyPiW98bpkARAS4B3OQP: Dei V
# 4axKuDPr6WKcDCyh8vueTY: Luar La L
# 7iK8PXO48WeuP03g8YR51W: Myke Towers
# 0GM7qgcRCORpGnfcN2tCiB: Tainy
# 128ftF9X7Kd7Di2fq3wYVs: Jamby El Favo
# 4SsVbpTthjScTS7U2hmr1X: Arcángel
# 6w9ToX5slZ4uIdmD17hJ3c: Bryant Myers
# 52iwsT98xCoGgiGntTiR7K: Quevedo
# 2O8vbr4RYPpk6MRA4fio7u: Saiko
# 2LRoIwlKmHjgvigdNGBHNo: Feid
# 5J7rXWjtn5HzUkJ4Jet8Fr: Alvaro Diaz
# 1pf0MPKfKdvS8J779mS1Ay: Miky Woodz
# 12vb80Km0Ew53ABfJOepVz: Ñengo Flow
# 5bWUlnPx9OYKsLiUJrhCA1: Jon Z
# 2cPqdH7XMvwaBJEVjheH8g: Jay Wheeler
# 1bAftSH8umNcGZ0uyV7LMg: Duki
# 2R21vXR83lH98kGeO99Y66: Anuel AA
# 1RyvyyTE3xzB2ZywiAwp0i: Future
# 1URnnhqYAYcrqrcwql10ft: 21 Savage
# 6l3HvQ5sa6mXTsMTB19rO5: J. Cole
# 0QHgL1lAIqAw0HtD7YldmP: DJ Khaled
# 0Y5tJX1MQlPlqiwlOH1tJY: Travis Scott
# 5K4W6rqBFWDnAN6FQUkS6x: Kanye West
# 2YZyLoL8N0Wb9xBt1NhZWg: Kendrick Lamar
# 0c173mlxpT3dSFRgMO8XPh: Big Sean
# 5f7VJjfbwm532GiveGC0ZK: Lil Baby
# 0iEtIxbK0KxaSlF7G42ZOp: Metro Boomin
# 50co4Is1HCEo8bhOyUWKpn: Young Thug
# 2hlmm7s2ICUX0LVIhVFlZQ: Gunna
# 4O15NlyKLIASxsJ0PrXPfz: Lil Uzi Vert
# 13ubrt8QOOCPljQ2FL1Kca: A$AP Rocky
# 2jku7tDXc6XoB6MO2hFuqg: Tory Lanez
# 6oMuImdp5ZcFhWP0ESe6mG: Migos
# 20sxb77xiYeusSH8cVdatc: Meek Mill
# 2EMAnMvWE2eb56ToJVfCWs: Bryson Tiller
# 2HPaUgqeutzr3jx5a9WyDV: PARTYNEXTDOOR
# 699OTQXzgjhIYAHMy9RyPD: Playboi Carti
# 0rKRcoCpKA2jLHuIXXn80i: Octavian
# 1ZPGzmbFTn8GRjqTqnLiFE: Niklas Dee
# 4anaTI5qQtKKp5D6I5sgDp: Ulf Leo Sommer
# 4jsmk00NuPR1FfXqUCF1ac: treamiboii
# 1UEipeDjRtS1qnuhmKgmXg: Peter Plate
# 7oxHYIVHNg4JQdKnUe1HiQ: Damn Yury
# 6AFA7y2tNohNcpaLwDRyxx: KXXMA
# 0XRkZikEumDTaGGE9mW8HA: 2 Engel & Charlie
# 6vNAKgK5d74N1I0zTxRPDp: Tream
# 7tzELpzPjTq26pa5FT9ykz: Yung Yury
# 7I2JG3CcPawkeQPE7uypHJ: HBz
# 67SeoU54DvDpkDDXtWEoOc: MartinBepunkt
# 2HIP5sNZWkrPgSBWRk8XpA: SIRA
# 4TSAnyHn47PpS8S9ofOjYU: Lyfrix
# 6HU4BOe89xyKTjx5uPT3Gg: Pazoo
# 1ZyqnbV7Brg5LgyS4EZCUD: FiNCH
# 01toP8PPkzyiQdKgyXle10: LUZI
# 2Reg4IlIHtEGZHnSD4pphn: erobé
# 4FDj6mh458K7m9Txwyj2rt: Harris & Ford
# 7bzKgx8PQw6TCVDSD43pc1: Valexus
# 4V8LLVI7PbaPR0K2TGSxFF: Tyler, The Creator
# 3tlXnStJ1fFhdScmQeLpuG: Brent Faiyaz
# 57vWImR43h4CaDao012Ofp: Steve Lacy
# 73sIBHcqh3Z3NyqHKZ7FOL: Childish Gambino
# 1Bl6wpkWCQ4KVgnASpvzzA: BROCKHAMPTON
# 20wkVLutqVOYrc0kxFs7rA: Daniel Caesar
# 3A5tHz1SfngyOZM2gItYKu: Earl Sweatshirt
# 4LLpKhyESsyAXpc4laK94U: Mac Miller
# 360IAlyVv4PCEVjgyMZrxK: Miguel
# 13ubrt8QOOCPljQ2FL1Kca: A$AP Rocky
# 7GN9PivdemQRKjDt4z5Zv8: The Internet
# 2P5sC9cVZDToPxyomzF1UH: Joey Bada$$
# 0fA0VVWsXO9YnASrzqfmYu: Kid Cudi
# 2ICR2m4hOBPhaYiZB3rnLW: Sonder
# 1anyVhU62p31KFi8MEzkbf: Chance the Rapper
# 2YZyLoL8N0Wb9xBt1NhZWg: Kendrick Lamar
# 5xpkLC1MxiPRiIJUDEzuVm: Odd Future
# 7tYKF4w9nC0nq9CsPZTHyP: SZA
# 5SXuuuRpukkTvsLuUknva1: Baby Keem
# 1U1el3k54VvEUzo3ybLPlM: Kali Uchis
# 20sx3E16MRur3wr3T9lWrt: Bitschu Batschu
# 50KbwRJgMFxSmT50FamuDN: Anna Ullrich
# 2GuGKV3bZJDQz0ILqbvBrB: DJ LUVHUNTAH
# 5w2AnakbHiabcr3RZPLqr5: Butschi
# 5HgSrauRrOxaH1tIt91d6i: Dj Schinkensuppe
# 2mhqonR8RAVkUxGYW3Aohu: DJ HENNE
# 5lfBKsGklvSAF0CKmQ7BBC: DJ YARAK
# 1UblhLM5FhgfdZDSzyispY: DJ Mischkonsum
# 2GU51XIk7oaP6rUrPOwK7c: DJ Local B
# 32EPfJgEPYMc9W0qTJPGjl: Cleopard2000
# 2Mm1h6fUugx92tOcPa4Jxj: Sita Messer
# 6IPWduBm255hSxmAcNoHjF: mischluft
# 7HhJcgi8uvsPx65JkoPE9V: Jath
# 2z5MSIstgHtruYoMdI0eKu: Bovskey
# 5zKJhJZNLAQoVoycu4Esnw: Trancemaster Krause
# 2MSbkxRSgodGAjqMTqxjo7: Justin Tinderdate
# 77Hrd76sBOVpMUyVZu5FPi: LIEBCOZY
# 0dmaRGobOPYVt4t4GVbw00: Bernossi
# 1YAXvPP9indIwd27HpEDF1: Paraçek
# 33cijwQi64u0TtdBhFtAy3: para//e/
# 2lnekSabtgxkHRWSb13o64: Klatschkind
# 3FzG2HgsgPRfwpX1qSK1g8: Mark Dekoda
# 46g2NeMi2Pq1yRP3CHnov8: Pappenheimer
# 3feOSXm5By7BCxuBwa2wbb: Talstrasse 3-5
# 0TlCQceVWdBUWl42a5B28A: A.N.A.L.
# 01hclCXcsqbdxfS4jtBCtM: Jason Lemm
# 3HjYDl4e63JOryBJ77SP2V: Minupren
# 07vNMZfNvVVmo0Ajvj8foo: Die Gebrüder Brett
# 2HO9NyE2I0NzcdWiPudztz: MoshTekk
# 1jV311C5ADuBqCPpprsjUp: Klanglos
# 5yePldMswAMD9fvIfRUc2o: Droplex
# 0JMIxWrqwOfyroCqEIKBBJ: TCHNKND
# 4smTLJEoRPULdc4QuG7JGo: Ben Dust
# 5X3rdmEE2Mif6kFQkb2PxB: Neelix
# 0OOYENnDrb4vWRx7iVVLM1: Schleini
# 1ZaV7vibPmLl5OCje4RRgZ: The Holy Santa Barbara
# 6kzCLJOC7MU8mAbhIJNpIo: Alfred Heinrichs
# 4OWNHq6tL2TBSQgyzeu2Tw: Sitte
# 1YQg0jqLV5RT98HjMXxzaO: TheDoDo
# 5yYwA7jmFlU01EKoLfeNpV: KomaCasper
# 0qT79UgT5tY4yudH9VfsdT: Sum 41
# 5aYyPjAsLj7UzANzdupwnS: Good Charlotte
# 3Ayl7mCk0nScecqOzvNp6s: Jimmy Eat World
# 3zxKH0qp3nBCuPZCZT5Vaf: Yellowcard
# 5ND0mGcL9SKSjWIjPd0xIb: Bowling For Soup
# 3vAaWhdBR38Q02ohXqaNHT: The All-American Rejects
# 7xklw3WodFZiNNmQt3DIgp: Angels & Airwaves
# 4ghjRm4M2vChDfTUycx0Ce: New Found Glory
# 7gkRNHOOt7QfhhXf0rEnmj: +44
# 2p4FqHnazRucYQHyDCdBrJ: Simple Plan
# 5LfGQac0EIXyAN8aUwmNAQ: The Offspring
# 0DK7FqcaL3ks9TfFn9y1sD: Box Car Racer
# 7oPftvlwr6VrsViSDV7fJY: Green Day
# 6Wr3hh341P84m3EI8qdn9O: Rise Against
# 46gyXjRIvN1NL1eCB8GBxo: All Time Low
# 1SImpQO0GbjRgvlwCcCtFo: The Red Jumpsuit Apparatus
# 55VydwMyCuGcavwPuhutPL: The Used
# 7FBcuc1gsnv6Y1nwFtNRCb: My Chemical Romance
# 4NiJW4q9ichVqL1aUsgGAN: A Day To Remember
# 19I4tYiChJoxEO5EuviXpz: AFI
# 78HKXj2z44JthdgoqT9ElL: DREAM DJ TEAM
# 20sx3E16MRur3wr3T9lWrt: Bitschu Batschu
# 0J6O3hpgsYbATxJGIakw0l: Bibisilvija
# 4op9PVwV13vzIsKyNiYbpX: Gerald VDH
# 77Hrd76sBOVpMUyVZu5FPi: LIEBCOZY
# 5HgSrauRrOxaH1tIt91d6i: Dj Schinkensuppe
# 6IPWduBm255hSxmAcNoHjF: mischluft
# 1yoE3BZmd9dS8xY9JnUwmw: Diskoromantik
# 2mhqonR8RAVkUxGYW3Aohu: DJ HENNE
# 4cohcn6lAkdQIAt3q5C4e2: BIBIZA
# 7HhJcgi8uvsPx65JkoPE9V: Jath
# 0gva8UY2TIdlH23NORfsml: Dale Fairbairn
# 7JmNUb5QPlIV4psjRqNsID: Eli Preiss
# 5lfBKsGklvSAF0CKmQ7BBC: DJ YARAK
# 2Mm1h6fUugx92tOcPa4Jxj: Sita Messer
# 7AkaRihy2hr1tjUXsjYK9x: DLV
# 2GuGKV3bZJDQz0ILqbvBrB: DJ LUVHUNTAH
# 5BMnIDhlF7NbpuiNgkyD9b: prodbypengg
# 52XYHIHtB7n8LGXuqrTUSk: Der traurige Gärtner
# 1oBQPdm35NiPSEWIx8Yl24: Wolfram
# 7oxHYIVHNg4JQdKnUe1HiQ: Damn Yury
# 1ZPGzmbFTn8GRjqTqnLiFE: Niklas Dee
# 6k9e4mFFVtEAAhGdvJBtqB: Luca-Dante Spadafora
# 6AFA7y2tNohNcpaLwDRyxx: KXXMA
# 2Reg4IlIHtEGZHnSD4pphn: erobé
# 4TSAnyHn47PpS8S9ofOjYU: Lyfrix
# 0LMiaB3r5vBn8zYpfZWeg9: Pbb Yea
# 0rKRcoCpKA2jLHuIXXn80i: Octavian
# 2HIP5sNZWkrPgSBWRk8XpA: SIRA
# 3yDixC6rzq0qg2HmZTobCO: BroyS
# 2Lg7y5DHmBMrxRI6Y4ThfU: Romero
# 7v5NBcbJPldtdx1S2zQRtZ: AyVe
# 7uK2QScoOUkqq8tvtvBIL7: Endzone
# 6l8dHVPkuEFzpQjhCH4xXT: JBS
# 6nJEMDVNcq7fduXgk7EdGG: MilleniumKid
# 2SRd7Kx7xWkZjoaFKgEreg: Paul
# 7bzKgx8PQw6TCVDSD43pc1: Valexus
# 5NR56DNAECf6yIARetflYe: VibeM
# 6CP5wWvO8oIxedESJNCN4H: Ski Aggu
# 744jIBAAvzMa5eVtUZDxR1: Liaze
# 78HKXj2z44JthdgoqT9ElL: DREAM DJ TEAM
# 50KbwRJgMFxSmT50FamuDN: Anna Ullrich
# 2GU51XIk7oaP6rUrPOwK7c: DJ Local B
# 2mhqonR8RAVkUxGYW3Aohu: DJ HENNE
# 5HgSrauRrOxaH1tIt91d6i: Dj Schinkensuppe
# 5w2AnakbHiabcr3RZPLqr5: Butschi
# 2GuGKV3bZJDQz0ILqbvBrB: DJ LUVHUNTAH
# 2n7VLaVMlGpxqmt05OiMCB: DJ GUESTLIST
# 5lfBKsGklvSAF0CKmQ7BBC: DJ YARAK
# 1UblhLM5FhgfdZDSzyispY: DJ Mischkonsum
# 32EPfJgEPYMc9W0qTJPGjl: Cleopard2000
# 6IPWduBm255hSxmAcNoHjF: mischluft
# 5zKJhJZNLAQoVoycu4Esnw: Trancemaster Krause
# 7HhJcgi8uvsPx65JkoPE9V: Jath
# 3cqcTPSscmPRwg2cDvUXxf: DJ Sonnenbrand
# 3dVLAQxTTr1HmDd4Wgva93: DJ HÖRDE
# 1YAXvPP9indIwd27HpEDF1: Paraçek
# 2MSbkxRSgodGAjqMTqxjo7: Justin Tinderdate
# 4887FTCAl0wdw3jwpkGq6d: Heggemann
# 1PDYN3Sl8i3tLsn6eTqC5r: Lenny Fuck
# 2pWTB3Q2GjoZpznmktG6uC: Replay Okay
# 7rlplvcY6ubrKGdhRJUvuV: skrt cobain
# 3XZewrXpRQqqCMuUMAIhvN: Domiziana
# 2PBBBcDggmGWyvOY9HXmKZ: DANZINGER 99
# 4wIBlvOhBSFNIAY7Gyht3h: ilyproxy
# 6mIDWMSkPgBJhOo4jzMqI4: EN6O
# 1emgDf5qBtbL909f2Pt7uP: 3LNA
# 0CzoJbqBbtBNLArLyAFDPn: Ikkimel
# 4K4YcztlZuVsfmd3aXWMN3: SHOKI
# 5HgSrauRrOxaH1tIt91d6i: Dj Schinkensuppe
# 59p191nMLthshvixS3w3x3: Saiya Tiaw
# 1SF4jakSq8kI38MYjFdaJG: Verifiziert
# 2WZCpsGLdNU1xENRwETylI: Kev Koko
# 4ehP4q7oBt5xGv3Ep0O0MS: viko63
# 5PKNAQEEXyfYEmteXrSCGI: SWEETBOYBLONDEY
# 4UQMmaBsYL00cUUICEMxSU: NEUNUNDNEUNZIG
# 0BRUlYcw8Rr4MGHe8kRgTv: Filow
# 7JmNUb5QPlIV4psjRqNsID: Eli Preiss
# 0zw17mk0oEnrv4STjNgxsr: beslik
# 70Rt4lMiib6ya5azoVK51v: TYM

# %%
ids_artists.extend(ids_similar_artists)
ids_artists = list(set(ids_artists))
print(f'Number of artists (without repetitions): {len(ids_artists)}')
# Out:
# Number of artists (without repetitions): 358

# %%
def get_new_releases(sp, limit=20):
    '''
    This function uses a Spotify client 'sp' to fetch new releases. It uses a .pickle file in the 
    'spotify_data_cache' directory as a cache to store and efficiently access the data. 
    It returns the album data with a default limit that can be adjusted.
    '''

    cache_file = os.path.join(CACHE_DIR, 'new_releases_cache.pickle')

    if os.path.exists(cache_file):
        try:
            with open(cache_file, 'rb') as file:
                new_releases = pickle.load(file)
            return new_releases
        except Exception as e:
            print(f"Error reading from the cache: {e}")

    try:
        new_releases = sp.new_releases(limit=limit)['albums']
        with open(cache_file, 'wb') as file:
            pickle.dump(new_releases, file)
        return new_releases
    except Exception as e:
        print(f"Error fetching new releases: {e}")
        return None

new_releases_data = get_new_releases(sp)

# %%
def getting_id_artists(df):

    print('')
    print('Artists with new releases')
    print('=====================')
    for item in df['items']:
        artist_id = item['artists'][0]['id']
        artist_name = item['artists'][0]['name']
        album_name = item['name']  
        release_date = item['release_date']
        print(f'{artist_id}: {artist_name} - // {album_name}, {release_date}')
        ids_artists.append(artist_id)
    return ids_artists

# %%
ids_artists = getting_id_artists(new_releases_data)
# Out:
# Artists with new releases
# =====================
# 1Mw40k757jZuiL0NIJpdO5: GULEED - // Cuando Menos Lo Espera, 2023-07-07
# 6k8mwkKJKKjBILo7ypBspl: Ana Mena - // bellodrama, 2023-03-24
# 7iK8PXO48WeuP03g8YR51W: Myke Towers - // LA VIDA ES UNA, 2023-03-23
# 5XJDexmWFLWOkjOEjOVX3e: Eladio Carrion - // 3MEN2 KBRN, 2023-03-17
# 790FomKkXshlbRYZFtlgla: KAROL G - // MAÑANA SERÁ BONITO, 2023-02-24
# 2auC28zjQyVTsiZKNgPRGs: RM - // Indigo, 2022-12-02
# 6KImCVD70vtIoJWnq6nGn3: Harry Styles - // Harry's House, 2022-05-20
# 4q3ewBCX7sLwd24euuV69X: Bad Bunny - // Un Verano Sin Ti, 2022-05-06
# 2R21vXR83lH98kGeO99Y66: Anuel AA - // Las Leyendas Nunca Mueren, 2021-11-26
# 4dpARuHxo51G3z768sgnrY: Adele - // 30, 2021-11-19
# 6eUKZXaKkcviH0Ku9w2n3V: Ed Sheeran - // =, 2021-10-29
# 4gzpq5DPGxSnKTe4SA8HAU: Coldplay - // Music Of The Spheres, 2021-10-15
# 53KwLdlmrlCelAZMaLVZqU: James Blake - // Friends That Break Your Heart, 2021-10-08
# 4MzJMcHQBl9SIYSjwWn8QW: Spiritbox - // Eternal Blue, 2021-09-17
# 1vyhD5VmyZ7KMfW5gqLgo5: J Balvin - // JOSE, 2021-09-10
# 5K4W6rqBFWDnAN6FQUkS6x: Kanye West - // Donda, 2021-08-29
# 3TVXtAsR1Inumwj472S9r4: Drake - // Certified Lover Boy, 2021-09-03
# 6nVcHLIgY5pE2YCl8ubca1: Jhayco - // Timelezz, 2021-09-03
# 6Xgp2XMz1fhVYe7i6yNAax: Trippie Redd - // Trip At Knight, 2021-08-20
# 163tK9Wjr9P9DmM0AVK7lm: Lorde - // Solar Power, 2021-08-20

# %%
ids_artists = list(set(ids_artists))
print(f'Number of artists (without repetitions): {len(ids_artists)}')
# Out:
# Number of artists (without repetitions): 372

# %%
def get_album_ids(sp, ids_artists,  CACHE_DIR='./spotify_data_cache', CACHE_FILE='artist_albums_cache.pickle'):
    '''
    Retrieves album IDs for each artist in 'ids_artists' using Spotify client 'sp'.
    Utilizes caching and a 3-second delay to avoid rate limiting.
    Returns a list of album IDs.
    '''

    os.makedirs(CACHE_DIR, exist_ok=True)
    cache_file_path = os.path.join(CACHE_DIR, CACHE_FILE)

    # Load cache if exists
    if os.path.exists(cache_file_path):
        with open(cache_file_path, 'rb') as file:
            cached_data = pickle.load(file)
    else:
        cached_data = {}

    id_albums = []
    nartists = len(ids_artists)

    for i, id_artist in enumerate(ids_artists):
        print(f'Processing artist {i+1} of {nartists}...')

        if id_artist in cached_data:
            id_albums.extend(cached_data[id_artist])
            continue

        try:
            albums = sp.artist_albums(id_artist, limit=1)  # to avoid having a huge list
            album_ids = [album['id'] for album in albums['items']]
            id_albums.extend(album_ids)
            cached_data[id_artist] = album_ids

            time.sleep(1)  # Adds 3-seconds delay

        except requests.exceptions.HTTPError as e:
            if e.response.status_code == 429:
                retry_after = int(e.response.headers.get('Retry-After', 3))
                print(f"Rate limit exceeded, waiting for {retry_after} seconds.")
                time.sleep(retry_after)
                continue
            else:
                print(f"Error processing artist {id_artist}: {e}")

    # Save updated cache
    with open(cache_file_path, 'wb') as file:
        pickle.dump(cached_data, file)

    print('Done!')
    return id_albums

# %%
id_albums = get_album_ids(sp, ids_artists)
# Out:
# Processing artist 1 of 372...
# Processing artist 2 of 372...
# Processing artist 3 of 372...
# Processing artist 4 of 372...
# Processing artist 5 of 372...
# Processing artist 6 of 372...
# Processing artist 7 of 372...
# Processing artist 8 of 372...
# Processing artist 9 of 372...
# Processing artist 10 of 372...
# Processing artist 11 of 372...
# Processing artist 12 of 372...
# Processing artist 13 of 372...
# Processing artist 14 of 372...
# Processing artist 15 of 372...
# Processing artist 16 of 372...
# Processing artist 17 of 372...
# Processing artist 18 of 372...
# Processing artist 19 of 372...
# Processing artist 20 of 372...
# Processing artist 21 of 372...
# Processing artist 22 of 372...
# Processing artist 23 of 372...
# Processing artist 24 of 372...
# Processing artist 25 of 372...
# Processing artist 26 of 372...
# Processing artist 27 of 372...
# Processing artist 28 of 372...
# Processing artist 29 of 372...
# Processing artist 30 of 372...
# Processing artist 31 of 372...
# Processing artist 32 of 372...
# Processing artist 33 of 372...
# Processing artist 34 of 372...
# Processing artist 35 of 372...
# Processing artist 36 of 372...
# Processing artist 37 of 372...
# Processing artist 38 of 372...
# Processing artist 39 of 372...
# Processing artist 40 of 372...
# Processing artist 41 of 372...
# Processing artist 42 of 372...
# Processing artist 43 of 372...
# Processing artist 44 of 372...
# Processing artist 45 of 372...
# Processing artist 46 of 372...
# Processing artist 47 of 372...
# Processing artist 48 of 372...
# Processing artist 49 of 372...
# Processing artist 50 of 372...
# Processing artist 51 of 372...
# Processing artist 52 of 372...
# Processing artist 53 of 372...
# Processing artist 54 of 372...
# Processing artist 55 of 372...
# Processing artist 56 of 372...
# Processing artist 57 of 372...
# Processing artist 58 of 372...
# Processing artist 59 of 372...
# Processing artist 60 of 372...
# Processing artist 61 of 372...
# Processing artist 62 of 372...
# Processing artist 63 of 372...
# Processing artist 64 of 372...
# Processing artist 65 of 372...
# Processing artist 66 of 372...
# Processing artist 67 of 372...
# Processing artist 68 of 372...
# Processing artist 69 of 372...
# Processing artist 70 of 372...
# Processing artist 71 of 372...
# Processing artist 72 of 372...
# Processing artist 73 of 372...
# Processing artist 74 of 372...
# Processing artist 75 of 372...
# Processing artist 76 of 372...
# Processing artist 77 of 372...
# Processing artist 78 of 372...
# Processing artist 79 of 372...
# Processing artist 80 of 372...
# Processing artist 81 of 372...
# Processing artist 82 of 372...
# Processing artist 83 of 372...
# Processing artist 84 of 372...
# Processing artist 85 of 372...
# Processing artist 86 of 372...
# Processing artist 87 of 372...
# Processing artist 88 of 372...
# Processing artist 89 of 372...
# Processing artist 90 of 372...
# Processing artist 91 of 372...
# Processing artist 92 of 372...
# Processing artist 93 of 372...
# Processing artist 94 of 372...
# Processing artist 95 of 372...
# Processing artist 96 of 372...
# Processing artist 97 of 372...
# Processing artist 98 of 372...
# Processing artist 99 of 372...
# Processing artist 100 of 372...
# Processing artist 101 of 372...
# Processing artist 102 of 372...
# Processing artist 103 of 372...
# Processing artist 104 of 372...
# Processing artist 105 of 372...
# Processing artist 106 of 372...
# Processing artist 107 of 372...
# Processing artist 108 of 372...
# Processing artist 109 of 372...
# Processing artist 110 of 372...
# Processing artist 111 of 372...
# Processing artist 112 of 372...
# Processing artist 113 of 372...
# Processing artist 114 of 372...
# Processing artist 115 of 372...
# Processing artist 116 of 372...
# Processing artist 117 of 372...
# Processing artist 118 of 372...
# Processing artist 119 of 372...
# Processing artist 120 of 372...
# Processing artist 121 of 372...
# Processing artist 122 of 372...
# Processing artist 123 of 372...
# Processing artist 124 of 372...
# Processing artist 125 of 372...
# Processing artist 126 of 372...
# Processing artist 127 of 372...
# Processing artist 128 of 372...
# Processing artist 129 of 372...
# Processing artist 130 of 372...
# Processing artist 131 of 372...
# Processing artist 132 of 372...
# Processing artist 133 of 372...
# Processing artist 134 of 372...
# Processing artist 135 of 372...
# Processing artist 136 of 372...
# Processing artist 137 of 372...
# Processing artist 138 of 372...
# Processing artist 139 of 372...
# Processing artist 140 of 372...
# Processing artist 141 of 372...
# Processing artist 142 of 372...
# Processing artist 143 of 372...
# Processing artist 144 of 372...
# Processing artist 145 of 372...
# Processing artist 146 of 372...
# Processing artist 147 of 372...
# Processing artist 148 of 372...
# Processing artist 149 of 372...
# Processing artist 150 of 372...
# Processing artist 151 of 372...
# Processing artist 152 of 372...
# Processing artist 153 of 372...
# Processing artist 154 of 372...
# Processing artist 155 of 372...
# Processing artist 156 of 372...
# Processing artist 157 of 372...
# Processing artist 158 of 372...
# Processing artist 159 of 372...
# Processing artist 160 of 372...
# Processing artist 161 of 372...
# Processing artist 162 of 372...
# Processing artist 163 of 372...
# Processing artist 164 of 372...
# Processing artist 165 of 372...
# Processing artist 166 of 372...
# Processing artist 167 of 372...
# Processing artist 168 of 372...
# Processing artist 169 of 372...
# Processing artist 170 of 372...
# Processing artist 171 of 372...
# Processing artist 172 of 372...
# Processing artist 173 of 372...
# Processing artist 174 of 372...
# Processing artist 175 of 372...
# Processing artist 176 of 372...
# Processing artist 177 of 372...
# Processing artist 178 of 372...
# Processing artist 179 of 372...
# Processing artist 180 of 372...
# Processing artist 181 of 372...
# Processing artist 182 of 372...
# Processing artist 183 of 372...
# Processing artist 184 of 372...
# Processing artist 185 of 372...
# Processing artist 186 of 372...
# Processing artist 187 of 372...
# Processing artist 188 of 372...
# Processing artist 189 of 372...
# Processing artist 190 of 372...
# Processing artist 191 of 372...
# Processing artist 192 of 372...
# Processing artist 193 of 372...
# Processing artist 194 of 372...
# Processing artist 195 of 372...
# Processing artist 196 of 372...
# Processing artist 197 of 372...
# Processing artist 198 of 372...
# Processing artist 199 of 372...
# Processing artist 200 of 372...
# Processing artist 201 of 372...
# Processing artist 202 of 372...
# Processing artist 203 of 372...
# Processing artist 204 of 372...
# Processing artist 205 of 372...
# Processing artist 206 of 372...
# Processing artist 207 of 372...
# Processing artist 208 of 372...
# Processing artist 209 of 372...
# Processing artist 210 of 372...
# Processing artist 211 of 372...
# Processing artist 212 of 372...
# Processing artist 213 of 372...
# Processing artist 214 of 372...
# Processing artist 215 of 372...
# Processing artist 216 of 372...
# Processing artist 217 of 372...
# Processing artist 218 of 372...
# Processing artist 219 of 372...
# Processing artist 220 of 372...
# Processing artist 221 of 372...
# Processing artist 222 of 372...
# Processing artist 223 of 372...
# Processing artist 224 of 372...
# Processing artist 225 of 372...
# Processing artist 226 of 372...
# Processing artist 227 of 372...
# Processing artist 228 of 372...
# Processing artist 229 of 372...
# Processing artist 230 of 372...
# Processing artist 231 of 372...
# Processing artist 232 of 372...
# Processing artist 233 of 372...
# Processing artist 234 of 372...
# Processing artist 235 of 372...
# Processing artist 236 of 372...
# Processing artist 237 of 372...
# Processing artist 238 of 372...
# Processing artist 239 of 372...
# Processing artist 240 of 372...
# Processing artist 241 of 372...
# Processing artist 242 of 372...
# Processing artist 243 of 372...
# Processing artist 244 of 372...
# Processing artist 245 of 372...
# Processing artist 246 of 372...
# Processing artist 247 of 372...
# Processing artist 248 of 372...
# Processing artist 249 of 372...
# Processing artist 250 of 372...
# Processing artist 251 of 372...
# Processing artist 252 of 372...
# Processing artist 253 of 372...
# Processing artist 254 of 372...
# Processing artist 255 of 372...
# Processing artist 256 of 372...
# Processing artist 257 of 372...
# Processing artist 258 of 372...
# Processing artist 259 of 372...
# Processing artist 260 of 372...
# Processing artist 261 of 372...
# Processing artist 262 of 372...
# Processing artist 263 of 372...
# Processing artist 264 of 372...
# Processing artist 265 of 372...
# Processing artist 266 of 372...
# Processing artist 267 of 372...
# Processing artist 268 of 372...
# Processing artist 269 of 372...
# Processing artist 270 of 372...
# Processing artist 271 of 372...
# Processing artist 272 of 372...
# Processing artist 273 of 372...
# Processing artist 274 of 372...
# Processing artist 275 of 372...
# Processing artist 276 of 372...
# Processing artist 277 of 372...
# Processing artist 278 of 372...
# Processing artist 279 of 372...
# Processing artist 280 of 372...
# Processing artist 281 of 372...
# Processing artist 282 of 372...
# Processing artist 283 of 372...
# Processing artist 284 of 372...
# Processing artist 285 of 372...
# Processing artist 286 of 372...
# Processing artist 287 of 372...
# Processing artist 288 of 372...
# Processing artist 289 of 372...
# Processing artist 290 of 372...
# Processing artist 291 of 372...
# Processing artist 292 of 372...
# Processing artist 293 of 372...
# Processing artist 294 of 372...
# Processing artist 295 of 372...
# Processing artist 296 of 372...
# Processing artist 297 of 372...
# Processing artist 298 of 372...
# Processing artist 299 of 372...
# Processing artist 300 of 372...
# Processing artist 301 of 372...
# Processing artist 302 of 372...
# Processing artist 303 of 372...
# Processing artist 304 of 372...
# Processing artist 305 of 372...
# Processing artist 306 of 372...
# Processing artist 307 of 372...
# Processing artist 308 of 372...
# Processing artist 309 of 372...
# Processing artist 310 of 372...
# Processing artist 311 of 372...
# Processing artist 312 of 372...
# Processing artist 313 of 372...
# Processing artist 314 of 372...
# Processing artist 315 of 372...
# Processing artist 316 of 372...
# Processing artist 317 of 372...
# Processing artist 318 of 372...
# Processing artist 319 of 372...
# Processing artist 320 of 372...
# Processing artist 321 of 372...
# Processing artist 322 of 372...
# Processing artist 323 of 372...
# Processing artist 324 of 372...
# Processing artist 325 of 372...
# Processing artist 326 of 372...
# Processing artist 327 of 372...
# Processing artist 328 of 372...
# Processing artist 329 of 372...
# Processing artist 330 of 372...
# Processing artist 331 of 372...
# Processing artist 332 of 372...
# Processing artist 333 of 372...
# Processing artist 334 of 372...
# Processing artist 335 of 372...
# Processing artist 336 of 372...
# Processing artist 337 of 372...
# Processing artist 338 of 372...
# Processing artist 339 of 372...
# Processing artist 340 of 372...
# Processing artist 341 of 372...
# Processing artist 342 of 372...
# Processing artist 343 of 372...
# Processing artist 344 of 372...
# Processing artist 345 of 372...
# Processing artist 346 of 372...
# Processing artist 347 of 372...
# Processing artist 348 of 372...
# Processing artist 349 of 372...
# Processing artist 350 of 372...
# Processing artist 351 of 372...
# Processing artist 352 of 372...
# Processing artist 353 of 372...
# Processing artist 354 of 372...
# Processing artist 355 of 372...
# Processing artist 356 of 372...
# Processing artist 357 of 372...
# Processing artist 358 of 372...
# Processing artist 359 of 372...
# Processing artist 360 of 372...
# Processing artist 361 of 372...
# Processing artist 362 of 372...
# Processing artist 363 of 372...
# Processing artist 364 of 372...
# Processing artist 365 of 372...
# Processing artist 366 of 372...
# Processing artist 367 of 372...
# Processing artist 368 of 372...
# Processing artist 369 of 372...
# Processing artist 370 of 372...
# Processing artist 371 of 372...
# Processing artist 372 of 372...
# Done!

# %%
def get_track_ids(sp, id_albums, CACHE_DIR='./spotify_data_cache', CACHE_FILE='album_tracks_cache.pickle'):
    '''
    Retrieves track IDs for each album in 'id_albums' using Spotify client 'sp'.
    Utilizes a pickle file for caching and includes error handling for rate limits.
    Returns a list of track IDs.
    '''

    os.makedirs(CACHE_DIR, exist_ok=True)
    cache_file_path = os.path.join(CACHE_DIR, CACHE_FILE)

    if os.path.exists(cache_file_path):
        with open(cache_file_path, 'rb') as file:
            cached_data = pickle.load(file)
    else:
        cached_data = {}

    id_tracks = []
    nalbums = len(id_albums)
    cache_updated = False  # Flag to track if new data has been added to cache

    for i, id_album in enumerate(id_albums):
        print(f'Processing album {i+1} of {nalbums}...')

        if id_album in cached_data:
            id_tracks.extend(cached_data[id_album])
        else:
            try:
                album_tracks = sp.album_tracks(id_album, limit=1)
                track_ids = [track['id'] for track in album_tracks['items']]
                id_tracks.extend(track_ids)
                cached_data[id_album] = track_ids
                cache_updated = True  # Set flag to true as new data is added

                time.sleep(1)  # Adds a 2-second delay

            except requests.exceptions.HTTPError as e:
                if e.response.status_code == 429:
                    retry_after = int(e.response.headers.get('Retry-After', 2))
                    print(f"Rate limit exceeded, waiting for {retry_after} seconds.")
                    time.sleep(retry_after)
                    continue  # Re-attempt the current album
                else:
                    print(f"Error processing album {id_album}: {e}")

    # Save updated cache only if new data has been added
    if cache_updated:
        with open(cache_file_path, 'wb') as file:
            pickle.dump(cached_data, file)
        print("Cache updated with new data.")

    print(f'Done! Total number of pre-candidate tracks: {len(id_tracks)}')
    return id_tracks

# %% [markdown]
# id_tracks = []
# nalbums = len(id_albums)
# for i, id_album in enumerate(id_albums):
#     print(f'Processing album {i+1} of {nalbums}...')
#     album_tracks = sp.album_tracks(id_album, limit=3)
#     for track in album_tracks['items']:
#         id_tracks.append(track['id'])
#
#     time.sleep(2)  # Adds 3-seconds delay
#
# print(f'Done! Total number of pre-candidate tracks: {len(id_tracks)}')

# %%
id_tracks = get_track_ids(sp, id_albums)
# Out:
# Processing album 1 of 6853...

# %%
def get_track_details_and_features(sp, id_tracks, CACHE_DIR='./spotify_data_cache', CACHE_FILE='track_features_cache.pickle'):
    '''
    Retrieves track details and audio features for each track in 'id_tracks' using Spotify client 'sp'.
    Utilizes a pickle file for caching and includes error handling for rate limits.
    Returns a DataFrame with track names and features.
    '''

    os.makedirs(CACHE_DIR, exist_ok=True)
    cache_file_path = os.path.join(CACHE_DIR, CACHE_FILE)

    if os.path.exists(cache_file_path):
        with open(cache_file_path, 'rb') as file:
            cached_data = pickle.load(file)
    else:
        cached_data = {}

    track_names = []
    features = []
    ntracks = len(id_tracks)

    for i, track_id in enumerate(id_tracks):
        print(f'Processing track {i+1} of {ntracks}...')

        if track_id not in cached_data:
            track_details = sp.track(track_id)
            track_name = track_details['name']
            audio_features = sp.audio_features(track_id)

            if audio_features[0] is not None:
                cached_data[track_id] = {'name': track_name, 'features': audio_features[0]}
                with open(cache_file_path, 'wb') as file:
                    pickle.dump(cached_data, file)

            time.sleep(2)  # Adds a 2-second delay to avoid rate limits

        if track_id in cached_data:
            track_names.append(cached_data[track_id]['name'])
            features.append(cached_data[track_id]['features'])

    print('Done!')
    candidates_df = pd.DataFrame(features, index=track_names)
    
    candidates_clean = cleaning_df(candidates_df)

    csv_file_path = './spotify_data_cache/candidates.csv'
    if os.path.exists(csv_file_path):
        existing_data = pd.read_csv(csv_file_path)
        updated_data = pd.concat([existing_data, candidates_clean]).drop_duplicates()
    else:
        updated_data = candidates_clean

    updated_data.to_csv(csv_file_path, index=False)
    print("CSV file updated.")

    return updated_data

# %%
updated_data  = get_track_details_and_features(sp, id_tracks)
# Out:
# Processing track 1 of 2238...
# Processing track 2 of 2238...
# Processing track 3 of 2238...
# Processing track 4 of 2238...
# Processing track 5 of 2238...
# Processing track 6 of 2238...
# Processing track 7 of 2238...
# Processing track 8 of 2238...
# Processing track 9 of 2238...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\Felix\Documents\Ironhack\Projects\Final-project\part2.ipynb Cell 26 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Felix/Documents/Ironhack/Projects/Final-project/part2.ipynb#X46sZmlsZQ%3D%3D?line=0'>1</a> updated_data  = get_track_details_and_features(sp, id_tracks)
#
# c:\Users\Felix\Documents\Ironhack\Projects\Final-project\part2.ipynb Cell 26 line 3
#      <a href='vscode-notebook-cell:/c%3A/Users/Felix/Documents/Ironhack/Projects/Final-project/part2.ipynb#X46sZmlsZQ%3D%3D?line=32'>33</a>         with open(cache_file_path, 'wb') as file:
#      <a href='vscode-notebook-cell:/c%3A/Users/Felix/Documents/Ironhack/Projects/Final-project/part2.ipynb#X46sZmlsZQ%3D%3D?line=33'>34</a>             pickle.dump(cached_data, file)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Felix/Documents/Ironhack/Projects/Final-project/part2.ipynb#X46sZmlsZQ%3D%3D?line=35'>36</a>     time.sleep(2)  # Adds a 2-second delay to avoid rate limits
#      <a href='vscode-notebook-cell:/c%3A/Users/Felix/Documents/Ironhack/Projects/Final-project/part2.ipynb#X46sZmlsZQ%3D%3D?line=37'>38</a> if track_id in cached_data:
#      <a href='vscode-notebook-cell:/c%3A/Users/Felix/Documents/Ironhack/Projects/Final-project/part2.ipynb#X46sZmlsZQ%3D%3D?line=38'>39</a>     track_names.append(cached_data[track_id]['name'])
#
# KeyboardInterrupt:

# %%
top_tracks_clean_mtx = top_tracks_clean.iloc[:,1:].values
candidatos_mtx = updated_data.iloc[:,1:].values
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Felix\Documents\Ironhack\Projects\Final-project\part2.ipynb Cell 27 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/Felix/Documents/Ironhack/Projects/Final-project/part2.ipynb#X51sZmlsZQ%3D%3D?line=0'>1</a> top_tracks_clean_mtx = top_tracks_clean.iloc[:,1:].values
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Felix/Documents/Ironhack/Projects/Final-project/part2.ipynb#X51sZmlsZQ%3D%3D?line=1'>2</a> candidatos_mtx = updated_data.iloc[:,1:].values
#
# NameError: name 'updated_data' is not defined

# %%
scaler = StandardScaler()
t20_scaled = scaler.fit_transform(top_tracks_clean_mtx)
can_scaled = scaler.fit_transform(candidatos_mtx)
t20_norm = np.sqrt((t20_scaled*t20_scaled).sum(axis=1))
can_norm = np.sqrt((can_scaled*can_scaled).sum(axis=1))
nt20 = t20_scaled.shape[0]
ncan = can_scaled.shape[0]
t20 = t20_scaled/t20_norm.reshape(nt20,1)
can = can_scaled/can_norm.reshape(ncan,1)
cos_sim = linear_kernel(t20,can)
cos_sim.shape

# %%
def obtener_candidatos(pos, cos_sim, ncands, umbral = 0.8):
    
    # Obtener todas las pistas candidatas por encima de umbral
    
    idx = np.where(cos_sim[pos,:]>=umbral)[0] 
    
    # Y organizarlas de forma descendente (por similitudes de mayor a menor)
    idx = idx[np.argsort(cos_sim[pos,idx])[::-1]] # [::-1] porque por defecto argsort organiza de manera ascendente

    # Si hay más de "ncands", retornar máximo "ncands"
    if len(idx) >= ncands:
        cands = idx[0:ncands]
    else:
        cands = idx
  
    return cands

# %%
ids_t20 = []
ids_playlist = []

for i in range(top_tracks_clean_mtx.shape[0]):
    print(top_tracks_clean_mtx.index[i]) 
    ids_t20.append(top_tracks_clean_mtx['id'][i])
    
    cands = obtener_candidatos(i, cos_sim, 5, umbral=0.8)
    
    if len(cands)==0:
        print('     ***No se encontraron pistas relacionadas***')
    else:
        for j in cands:
            id_cand = candidatos_mtx['id'][j]
            ids_playlist.append(id_cand)
            
            print(f'   {candidatos_mtx.index[j]}')

# %%
ids_playlist_dep = [x for x in ids_playlist if x not in ids_t20]
ids_playlist_dep = list(set(ids_playlist_dep))

# %%
pl = sp.user_playlist_create(user=username, 
                             name='Spotipy Recommender Playlist', 
                             description="Playlist created with the recommendation system")

sp.playlist_add_items(pl['id'],ids_playlist_dep)
